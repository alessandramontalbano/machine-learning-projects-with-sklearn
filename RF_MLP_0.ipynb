# %% [markdown]
# # Individual project - 3029121
# ----------
#
# This dataset is composed of 1300 samples with 30 features each. The first column
# in the dataset represents the label. There are 5 labels. The remaining columns
# are numeric features.
#
# Your task is the following: you should compare the performance of the
# k-NearestNeighbors algorithm (implemented by
# sklearn.neighbors.KNeighborsClassifier) with that of a Random Forest
# (implemented by sklearn.ensemble.ExtraTreesClassifier). Try to optimize both
# algorithms' parameters and determine which one is best for this dataset. At the
# end of the analysis, you should have chosen an algorithm and its optimal set of
# parameters: write this choice explicitly in the conclusions of your notebook.
#
# Your notebook should detail the procedure you have used to choose the optimal
# parameters (graphs are a good idea when possible/sensible).
#
# The notebook will be evaluated not only based on the final results, but also on
# the procedure employed, which should balance practical considerations (one may
# not be able to exhaustively explore all possible combinations of the parameters)
# with the desire for achieving the best possible performance in the least amount
# of time.
#
# Bonus points may be assigned for particularly clean/nifty code and/or well-
# presented results.
#
# You are also free to attempt other strategies beyond the one in the assignment
# (which however is mandatory!).

# %% [markdown]
# --------------------------------------------------------------

# %% [markdown]
# The notebook is divided in:
#
# - Functions to use later
#
# - Data overview (statistics about the features,scatter plots for the features,correlation matrix, PCA)
#
# - KNN (hyperparameter tuning)
#
# - Random Forest (features importances, hyperparameter tuning)
#
# - Multilayer Perceptron (hyperparameter tuning)
#
# - Conclusions

# %%
# %matplotlib inline

# %%
import itertools
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import statsmodels.formula.api as sm
from sklearn.decomposition import PCA
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, accuracy_score
import seaborn as sns
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import KFold,GridSearchCV, RandomizedSearchCV

# %% [markdown]
# ### Load the dataset

# %%
df = pd.read_csv('mldata_0302912102.csv')
pd.set_option('display.max_columns', None)

# %% [markdown]
# "What percentage of my predictions are correct?" Accuracy score is used to measure performance of the various models used in this notebook.

# %% [markdown]
# ## Functions to use later

# %% [markdown]
# Training and testing on the same data is a methodological mistake, therefore it is better to dedicate a part of the dataset (in a mutually exclusive manner) to each phase.
#
# In other words, to avoid overfitting, it is reasonable to split the dataset into training set and test set: it is common to choose 70% (num_train = 910) and 30% (num_test = 390) as proportions.

# %%
all_data = 1300

# %% [markdown]
# Standardization of the dataset is a common requirement for neural networks; they might behave badly if the individual features do not more or less look like standard normally distributed data: gaussian with zero mean and unit variance. During standardization, I subtract to the test data the mean from the training data and then I divide all by the sd of the training data. Standardization, if not done in this way can cause considerable optimism bias in your model evaluation. (from The Elements of Statistical Learning, section 'The Right and Wrong Way to Do Cross Validation')
#
# Scikitlearn offers a variety of tools to scale the data. In this page I found a comparison of them http://scikit-learn.org/stable/auto_examples/preprocessing/plot_all_scaling.html. For what I've understood, in summary:
#
# - StandardScaler: assumes that data is normally distributed within each feature, and it'll scale them such that the distribution is centered around 0 with a standard deviation of 1.
# - MinMaxScaler: works well for cases when the distribution is not Gaussian or when the standard deviation is very small. However, it is sensitive to outliers.
# - Normalizer: scales each value by dividing each value by its magnitude in n-dimensional space for n number of features.
#
# By trial and error, I realized that Normalizer and MinMaxScaler perform very similar on this dataset, but I don't like the fact that they both don't take account of outliers. So I choose StandardScaler. Also do PCA.
#
# So I define a class for this purpose, very similar to MnistTrain.

# %%
class parse_data:
    def __init__(self, num_train = 910, num_test = 390, seed = 49176, normalize = True, n_components = 0.9):
        
        np.random.seed(seed)
        perm=np.random.permutation(all_data) #returns a permuted range
        pca_a = n_components is None or n_components > 0

        
        i_train=perm[:num_train] 
        i_valid=perm[num_train:num_train+num_test]

        train_data=features_1[i_train,:]
        train_target= target[i_train]
        test_data = features_1[i_valid,:]
        test_target = target[i_valid]
        
        # Normalize 
        if normalize:
            print('normalized')
            stand = StandardScaler()
            train_data_1 = stand.fit_transform(train_data) # fit only on training data
            test_data_1 = stand.transform(test_data) # apply same transformation to test data
        else:
            print('not normalized')
            train_data_1, test_data_1 = train_data, test_data
    
        if pca_a:
            pca = PCA(n_components = n_components) 
            pca.fit(train_data) 
            X = pca.transform(train_data_1)
            vX = pca.transform(test_data_1)
        else:
            X, vX = train_data_1, test_data_1
            
        nc = X.shape[1]
        print('nc=%i' % X.shape[1])
        
        self.perm = perm
        self.X, self.y = train_data_1, train_target
        self.vX, self.vy = test_data_1, test_target
        
    def train(self):
        return self.X, self.y
    
    def test(self):
        return self.vX, self.vy

# %% [markdown]
# I found this tutorial and modified the function: http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html

# %%
def plot_confusion_matrix(cm,labels,cmap_0=plt.cm.cool):

    plt.imshow(cm, interpolation='nearest', cmap=cmap_0)
    plt.title('Confusion matrix')
    plt.colorbar()
    
    plt.xticks(np.arange(len(labels)), labels, rotation=45) # write labels(0,1,2,3,4) on both axis
    plt.yticks(np.arange(len(labels)), labels)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %% [markdown]
# Function for k-fold cross validation:
# In k-fold cross-validation, the data is randomly split into k mutually exclusive subsets of approximately equal size. A learning algorithm is trained and tested k times; each time it is tested on one of the k folds and trained using the remaining k − 1 folds.
# The cross-validation estimate of accuracy is the overall number of correct classifications, divided by the number of examples in the data.
#
# Since I want to evalute all the models in consistent way and to reuse code I created the following function.

# %%
def kfold(model,n_splits,features,target):
    
    kfold=KFold(n_splits,shuffle=False) 
    #define two lists to save scores
    train_scores=[]
    validation_scores=[]
    for train_index, validation_index in kfold.split(features, target):
        X_train,X_validation,y_train,y_validation = features[train_index],features[validation_index],target[train_index],target[validation_index]

        probas_=model.fit(X_train,y_train).predict_proba(X_validation)
        train_score=model.score(X_train,y_train)
        validation_score=model.score(X_validation,y_validation)
        train_scores.append(train_score)
        validation_scores.append(validation_score)

        print("Training score = %g, Validation score = %g" % (train_score,validation_score))

    cv_score=np.mean(validation_scores)
    
    print("CV accuracy = %g" % (cv_score))
    return cv_score

# %%
d = {} # a dictonary to collect the models validation scores

# %% [markdown]
# ## Data overview

# %%
df.head()
# Out:
#    Unnamed: 0  label  num.feature 1  num.feature 2  num.feature 3  \
# 0           0      4      -0.989355       0.696484       2.529081
# 1           1      0      -0.692776       0.156864       1.159516
# 2           2      2      -0.375950      -0.413332      -2.183325
# 3           3      0       1.059014      -0.762486       2.834358
# 4           4      1       1.270210       0.679735      -0.937112
#
#    num.feature 4  num.feature 5  num.feature 6  num.feature 7  num.feature 8  \
# 0       2.269946       3.940082       1.164554      -1.638471      -2.171293
# 1      -2.083824       0.945848      -1.424155       1.301443       1.103776
# 2       1.677557      -1.351878       0.464383       0.420577      -2.854117
# 3      -3.760712       1.454733      -1.034777       3.512627       4.963899
# 4       2.112607      -0.558671      -0.632870       1.814271      -1.907396
#
#    num.feature 9  num.feature 10  num.feature 11  num.feature 12  \
# 0      -0.142533       -0.852128        1.439989        1.345495
# 1       0.519624       -0.919200        2.245466        0.997047
# 2       0.610403       -0.180338       -1.448823        1.953357
# 3       0.706470        0.454586        0.252623       -5.973895
# 4      -0.349884        0.014642       -1.007021        9.178173
#
#    num.feature 13  num.feature 14  num.feature 15  num.feature 16  \
# 0       -0.316946        3.183279        0.946044       -0.068368
# 1       -2.093709        0.304783        0.230346       -0.192135
# 2       -0.087714        0.580180       -1.329143       -1.070735
# 3        2.025086        0.222088        1.271142        0.088913
# 4       -3.326356        1.590834       -0.322111       -0.103629
#
#    num.feature 17  num.feature 18  num.feature 19  num.feature 20  \
# 0       -4.297011       -1.942174        2.081589        0.555241
# 1       -1.220168        0.556781        1.235929       -1.916344
# 2       -2.191239       -0.255459        1.165097       -1.274283
# 3        0.891999        1.083396        2.954949       -0.718685
# 4       -1.421705       -0.803265       -0.714062       -0.560966
#
#    num.feature 21  num.feature 22  num.feature 23  num.feature 24  \
# 0        0.203818        0.854203       -2.553534        0.997678
# 1       -0.389169        0.708360        1.236605        0.015395
# 2        1.057245       -0.847773       -0.389270        0.879515
# 3       -0.886193        1.027869        2.747832        0.036018
# 4       -0.028008        0.730399        3.097562        0.086836
#
#    num.feature 25  num.feature 26  num.feature 27  num.feature 28  \
# 0        0.278325       -0.433892        1.230472        0.752720
# 1       -1.002621        1.120569        0.768388       -0.777686
# 2       -0.931737       -0.229552        1.165055       -1.268103
# 3       -1.847472       -1.322725       -0.859430        1.024448
# 4        2.480328       -0.376720        0.405535       -3.534854
#
#    num.feature 29  num.feature 30
# 0       -0.521462        0.086304
# 1       -1.372062       -0.651913
# 2        0.368428       -0.954772
# 3       -3.542124        0.854517
# 4       -4.511786        0.359906

# %%
df.shape
# Out:
# (1300, 32)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 32 columns):
# Unnamed: 0        1300 non-null int64
# label             1300 non-null int64
# num.feature 1     1300 non-null float64
# num.feature 2     1300 non-null float64
# num.feature 3     1300 non-null float64
# num.feature 4     1300 non-null float64
# num.feature 5     1300 non-null float64
# num.feature 6     1300 non-null float64
# num.feature 7     1300 non-null float64
# num.feature 8     1300 non-null float64
# num.feature 9     1300 non-null float64
# num.feature 10    1300 non-null float64
# num.feature 11    1300 non-null float64
# num.feature 12    1300 non-null float64
# num.feature 13    1300 non-null float64
# num.feature 14    1300 non-null float64
# num.feature 15    1300 non-null float64
# num.feature 16    1300 non-null float64
# num.feature 17    1300 non-null float64
# num.feature 18    1300 non-null float64
# num.feature 19    1300 non-null float64
# num.feature 20    1300 non-null float64
# num.feature 21    1300 non-null float64
# num.feature 22    1300 non-null float64
# num.feature 23    1300 non-null float64
# num.feature 24    1300 non-null float64
# num.feature 25    1300 non-null float64
# num.feature 26    1300 non-null float64
# num.feature 27    1300 non-null float64
# num.feature 28    1300 non-null float64
# num.feature 29    1300 non-null float64
# num.feature 30    1300 non-null float64
# dtypes: float64(30), int64(2)
# memory usage: 325.1 KB

# %% [markdown]
# The dataset is composed by an unnamed:0 (which can be discarded since it doesn't provide any additional information), one label column containing 5 classes and 30 numeric features: all the columns are made up by 1300 datapoints.
# Elements of column label are of type int64, while the numerical features are float64 type.
# There are no categorical or missing data.

# %%
del df['Unnamed: 0']; #this column is of no use

# %%
df.describe()
# Out:
#              label  num.feature 1  num.feature 2  num.feature 3  \
# count  1300.000000    1300.000000    1300.000000    1300.000000
# mean      1.975385       0.107454       0.128261       0.501413
# std       1.428084       0.995871       0.982443       2.021299
# min       0.000000      -4.379624      -3.592241      -6.954433
# 25%       1.000000      -0.517270      -0.529884      -0.873019
# 50%       2.000000       0.080065       0.124125       0.514335
# 75%       3.000000       0.798925       0.770615       1.924380
# max       4.000000       4.007713       3.713299       7.011052
#
#        num.feature 4  num.feature 5  num.feature 6  num.feature 7  \
# count    1300.000000    1300.000000    1300.000000    1300.000000
# mean       -0.230926       0.520707       0.087226       0.308646
# std         3.127988       2.051358       1.048581       2.132979
# min       -12.567613      -6.352518      -3.719483      -8.540255
# 25%        -2.143952      -0.761841      -0.640300      -1.097167
# 50%        -0.119423       0.620551       0.067428       0.369378
# 75%         1.823479       1.942535       0.760603       1.827631
# max        10.038969       5.910143       4.016878       6.669147
#
#        num.feature 8  num.feature 9  num.feature 10  num.feature 11  \
# count    1300.000000    1300.000000     1300.000000     1300.000000
# mean        0.110610       0.096584        0.085532        0.092663
# std         2.017617       0.997752        1.003056        0.994222
# min        -5.580531      -3.529205       -3.013481       -2.595774
# 25%        -1.262826      -0.594931       -0.628594       -0.534831
# 50%         0.044461       0.129686        0.083619        0.102204
# 75%         1.434874       0.752711        0.764596        0.739728
# max         8.339811       3.740737        3.404136        3.348723
#
#        num.feature 12  num.feature 13  num.feature 14  num.feature 15  \
# count     1300.000000     1300.000000     1300.000000     1300.000000
# mean         0.844002       -0.332995        0.117748        0.023333
# std          4.332435        2.074367        1.026063        0.979169
# min        -14.745825       -7.483907       -3.632229       -2.995054
# 25%         -1.995452       -1.753753       -0.590342       -0.612027
# 50%          1.010699       -0.393122        0.105819        0.031003
# 75%          3.677920        0.940843        0.829541        0.676158
# max         13.992475        9.554341        3.661423        3.556800
#
#        num.feature 16  num.feature 17  num.feature 18  num.feature 19  \
# count     1300.000000     1300.000000     1300.000000     1300.000000
# mean         0.088195        0.142512        0.083243        0.238956
# std          0.974809        3.433575        1.003351        2.126235
# min         -2.799282      -12.677138       -3.370080       -6.115540
# 25%         -0.568535       -1.948411       -0.592053       -1.179167
# 50%          0.093399        0.219539        0.060091        0.246685
# 75%          0.751886        2.303244        0.742753        1.777583
# max          3.252411       11.387377        3.349580        6.215893
#
#        num.feature 20  num.feature 21  num.feature 22  num.feature 23  \
# count     1300.000000     1300.000000     1300.000000     1300.000000
# mean         0.078469        0.122070        0.133010        0.279274
# std          0.999656        0.995160        1.003849        1.934011
# min         -3.035090       -3.256327       -3.602980       -6.846494
# 25%         -0.584969       -0.538539       -0.514298       -0.935917
# 50%          0.079429        0.099088        0.139529        0.383332
# 75%          0.759112        0.792521        0.784006        1.602083
# max          3.445435        3.146330        3.870832        6.602046
#
#        num.feature 24  num.feature 25  num.feature 26  num.feature 27  \
# count     1300.000000     1300.000000     1300.000000     1300.000000
# mean         0.110048        0.319904        0.084683        0.097724
# std          1.022654        2.139898        0.987048        0.995790
# min         -4.457437       -6.645564       -3.379677       -2.961863
# 25%         -0.561009       -1.134048       -0.571230       -0.561005
# 50%          0.123352        0.295249        0.075460        0.107603
# 75%          0.748526        1.699583        0.788034        0.748582
# max          3.505898        7.170337        3.142983        3.232647
#
#        num.feature 28  num.feature 29  num.feature 30
# count     1300.000000     1300.000000     1300.000000
# mean        -0.120053       -0.100123        0.154620
# std          1.982215        2.121268        1.003440
# min         -6.929906       -7.742881       -3.059102
# 25%         -1.500282       -1.515127       -0.542564
# 50%         -0.113537       -0.042857        0.126959
# 75%          1.239055        1.331570        0.874869
# max          6.248632        6.416503        3.189749

# %% [markdown]
# It can be useful to divide the dataset in features and target:

# %%
features_1 = df.drop('label', axis=1).values
target = df['label'].values

# %% [markdown]
# Let's check how many elements of each class, if they're homogeneous or not.

# %%
print("label 0: " + str(df[df.label == 0].shape[0]))
print("label 1: " + str(df[df.label == 1].shape[0]))
print("label 2: " + str(df[df.label == 2].shape[0]))
print("label 3: " + str(df[df.label == 3].shape[0]))
print("label 4: " + str(df[df.label == 4].shape[0]))
# Out:
# label 0: 268
# label 1: 273
# label 2: 246
# label 3: 249
# label 4: 264

# %% [markdown]
# As we can see above, labels are quite homogenous

# %%
groups = df.groupby(['label'])
groups.agg([np.mean, np.min, np.max, np.std])
# Out:
#       num.feature 1                               num.feature 2            \
#                mean      amin      amax       std          mean      amin
# label
# 0          0.208151 -2.311429  2.896545  0.952192      0.185232 -2.229250
# 1          0.048233 -4.130152  2.331266  1.009008      0.059511 -3.050093
# 2          0.073923 -4.379624  3.228490  1.027992      0.087183 -2.555129
# 3         -0.021897 -2.762508  4.007713  0.996011      0.159113 -3.592241
# 4          0.219718 -3.587650  3.045454  0.980634      0.150697 -2.349145
#
#                           num.feature 3                                \
#            amax       std          mean      amin      amax       std
# label
# 0      3.713299  0.971063      0.935421 -4.712663  6.745804  1.856278
# 1      2.761836  0.928538      0.153984 -5.375672  5.403001  2.009963
# 2      2.274014  0.963201     -0.100556 -5.756555  4.564426  1.826717
# 3      2.925875  1.003650      1.329813 -4.038682  5.516112  1.782753
# 4      2.994894  1.045436      0.199697 -6.954433  7.011052  2.236197
#
#       num.feature 4                                 num.feature 5            \
#                mean       amin       amax       std          mean      amin
# label
# 0         -1.332482 -12.567613   7.087138  3.274853      1.058498 -3.267568
# 1          0.294193  -8.288219   9.573115  2.983653      0.244374 -4.299428
# 2         -0.391421  -7.960503   7.894744  2.909533     -0.057272 -6.338879
# 3          0.993709  -5.842198   8.149883  2.639263      0.149006 -6.352518
# 4         -0.661203 -12.399247  10.038969  3.259555      1.149672 -6.249787
#
#                           num.feature 6                                \
#            amax       std          mean      amin      amax       std
# label
# 0      5.560362  1.653846      0.129298 -3.719483  2.591635  1.006856
# 1      5.910143  2.034671      0.037551 -2.690847  3.186700  1.071273
# 2      5.425155  2.216156      0.240818 -2.582009  4.016878  1.083759
# 3      5.364295  2.101046      0.004957 -3.650123  2.599874  1.049978
# 4      5.644925  1.942625      0.030360 -2.585763  3.544704  1.022172
#
#       num.feature 7                               num.feature 8            \
#                mean      amin      amax       std          mean      amin
# label
# 0          1.090579 -3.081925  5.237360  1.565648      1.070235 -3.287250
# 1          0.350689 -4.743409  6.004651  2.140571     -0.834502 -5.476463
# 2         -0.085589 -4.092665  5.414649  1.926666      0.288052 -5.580531
# 3          0.144443 -6.426348  6.669147  2.267403     -1.034480 -4.433589
# 4         -0.006380 -8.540255  5.656049  2.458161      1.028463 -3.917747
#
#                           num.feature 9                                \
#            amax       std          mean      amin      amax       std
# label
# 0      5.916509  1.779741      0.137653 -2.397849  2.454652  0.931691
# 1      3.352329  1.606967      0.051785 -2.602200  2.366008  0.946533
# 2      8.339811  2.421755      0.038542 -3.481063  3.740737  1.058682
# 3      2.441424  1.406827      0.121573 -3.529205  2.998040  0.997455
# 4      5.031093  1.705279      0.131732 -2.650415  2.767707  1.057398
#
#       num.feature 10                               num.feature 11            \
#                 mean      amin      amax       std           mean      amin
# label
# 0           0.130142 -2.734291  2.634799  1.007624       0.176589 -2.595774
# 1           0.004370 -2.774798  2.664803  1.032404       0.008034 -2.386699
# 2           0.134151 -3.013481  2.263094  0.971232       0.027199 -2.197964
# 3           0.052173 -2.449440  2.316765  1.004045       0.135321 -2.417407
# 4           0.110337 -2.907215  3.404136  0.997110       0.115747 -2.498843
#
#                           num.feature 12                                  \
#            amax       std           mean       amin       amax       std
# label
# 0      3.053029  1.034808      -0.167338 -12.786717  13.662384  3.923978
# 1      3.059857  0.958356       3.583728  -6.225797  13.992475  3.946228
# 2      3.098769  0.932991       1.457982  -7.938164  10.991054  3.239811
# 3      3.348723  1.019124       2.215539  -8.860207  10.981651  3.274197
# 4      3.247284  1.016911      -2.828186 -14.745825   9.755115  4.071870
#
#       num.feature 13                               num.feature 14            \
#                 mean      amin      amax       std           mean      amin
# label
# 0          -0.023765 -7.375100  9.554341  2.521632       0.097963 -2.794686
# 1          -0.814625 -7.483907  2.505298  1.534433       0.161144 -2.695031
# 2          -0.927685 -6.880565  3.677577  1.820424       0.158345 -2.490853
# 3           0.003915 -5.577590  4.614609  2.050872       0.104978 -2.653663
# 4           0.087513 -4.687841  6.049647  2.086986       0.067172 -3.632229
#
#                           num.feature 15                                \
#            amax       std           mean      amin      amax       std
# label
# 0      3.018451  1.008557       0.121742 -2.494035  2.528455  1.000028
# 1      2.502018  1.006341      -0.022921 -2.485224  3.073476  0.938362
# 2      2.961870  1.003352       0.054854 -2.710877  3.556800  0.996299
# 3      2.706924  1.024943       0.018284 -2.995054  2.678573  1.018227
# 4      3.661423  1.088538      -0.053345 -2.773869  3.029096  0.942516
#
#       num.feature 16                               num.feature 17             \
#                 mean      amin      amax       std           mean       amin
# label
# 0           0.097229 -2.689753  3.252411  1.058993       0.355848  -4.484839
# 1           0.066541 -2.696883  2.719539  0.949899       1.449223  -7.099041
# 2           0.162252 -2.496036  2.643909  0.951148      -0.309239  -7.819219
# 3           0.010891 -2.799282  2.816392  0.989497      -0.737970 -11.320461
# 4           0.105321 -2.264053  2.513161  0.918730      -0.173907 -12.677138
#
#                            num.feature 18                                \
#             amax       std           mean      amin      amax       std
# label
# 0       5.373689  1.792040       0.075318 -3.043281  3.349580  0.993161
# 1      11.387377  3.133950       0.064086 -3.029321  3.292333  1.058829
# 2       7.527449  3.225602       0.109801 -2.702469  3.178142  0.964329
# 3       7.265102  3.649400       0.123756 -2.680262  3.347364  0.945974
# 4      11.206778  4.440368       0.048141 -3.370080  2.302314  1.047597
#
#       num.feature 19                               num.feature 20            \
#                 mean      amin      amax       std           mean      amin
# label
# 0           0.994401 -5.114650  5.284337  1.918400       0.129726 -2.668185
# 1          -0.855423 -5.658161  5.155411  2.010855       0.137084 -2.720934
# 2           0.169899 -6.115540  5.733248  2.154150       0.044639 -2.480423
# 3           0.862905 -5.434126  6.215893  1.933359       0.042373 -3.035090
# 4           0.079602 -5.280127  5.583275  2.083376       0.031392 -2.723683
#
#                           num.feature 21                                \
#            amax       std           mean      amin      amax       std
# label
# 0      3.076104  0.935663       0.101388 -2.929518  2.392083  0.974300
# 1      3.242977  1.057592       0.087913 -2.791433  2.964728  0.980771
# 2      2.883766  1.003828       0.110745 -3.122803  2.931420  1.059781
# 3      2.712699  1.007806       0.208427 -2.713675  3.146330  1.007349
# 4      3.445435  0.991456       0.107491 -3.256327  2.742841  0.959560
#
#       num.feature 22                               num.feature 23            \
#                 mean      amin      amax       std           mean      amin
# label
# 0           0.217218 -2.346144  2.679174  0.981598       1.025708 -3.124633
# 1           0.017268 -3.602980  2.870019  1.010869       1.135359 -6.846494
# 2           0.195708 -2.960648  3.063490  1.081019       0.183190 -4.420087
# 3           0.071236 -2.958950  2.525012  0.998800       0.024116 -5.222059
# 4           0.167056 -3.300226  3.870832  0.939859      -1.033548 -5.430736
#
#                           num.feature 24                                \
#            amax       std           mean      amin      amax       std
# label
# 0      6.602046  1.652599       0.107901 -2.365288  3.505898  1.053401
# 1      4.327867  1.610410      -0.007391 -2.988271  2.751884  1.003417
# 2      5.504737  1.778984       0.194690 -2.526942  2.703924  0.952794
# 3      5.460243  2.072455       0.164182 -4.457437  3.170165  1.006451
# 4      5.157631  1.700745       0.103741 -4.238814  2.829782  1.083033
#
#       num.feature 25                               num.feature 26            \
#                 mean      amin      amax       std           mean      amin
# label
# 0          -0.702977 -4.299696  3.065509  1.426665       0.136346 -3.049825
# 1           1.104342 -3.892192  5.999348  1.971237       0.122656 -3.379677
# 2           0.189422 -6.284139  7.170337  2.467213       0.035297 -3.153382
# 3           0.969759 -5.906952  6.229953  1.916135       0.023499 -2.532686
# 4           0.055757 -6.645564  6.316366  2.282270       0.096698 -2.180107
#
#                           num.feature 27                                \
#            amax       std           mean      amin      amax       std
# label
# 0      2.844264  0.978351       0.124372 -2.961863  3.232647  1.036672
# 1      3.142983  0.975058       0.129524 -2.756546  2.530142  0.935840
# 2      2.926451  1.056838      -0.025344 -2.602109  2.829435  1.001462
# 3      3.048071  0.956971       0.057395 -2.709008  2.790312  1.007353
# 4      2.791783  0.970995       0.190501 -2.314194  2.931637  0.991754
#
#       num.feature 28                               num.feature 29            \
#                 mean      amin      amax       std           mean      amin
# label
# 0          -0.925690 -5.450191  3.836846  1.575575      -0.867456 -7.390761
# 1          -0.943964 -5.244041  3.257137  1.627755       0.165085 -7.742881
# 2          -0.837881 -6.929906  4.425573  1.995494      -0.042913 -6.436427
# 3           1.155932 -3.699136  5.681878  1.584508       0.074461 -4.673364
# 4           1.015188 -4.204721  6.248632  1.840193       0.186613 -6.537619
#
#                           num.feature 30
#            amax       std           mean      amin      amax       std
# label
# 0      4.529102  1.870293       0.124885 -2.883818  2.857882  1.078038
# 1      5.011526  2.211947       0.131147 -3.059102  2.792229  1.000243
# 2      6.416503  1.856854       0.215745 -2.110739  2.456937  0.976156
# 3      6.265187  2.152513       0.068495 -2.788798  3.189749  0.995947
# 4      6.350208  2.290276       0.233355 -2.348954  3.132702  0.957822

# %% [markdown]
# The table above shows some statistics about all the features, grouped by label. Given that the features have different mean and standard deviation I should standardize them, but later.

# %% [markdown]
# I wanted to plot histograms for each of the feature of the dataset, however I found that drawing a violin plot is easier and more intuitive.

# %%
plt.figure(figsize=(12, 5))
# Draw a violinplot with a narrower bandwidth than the default
sns.violinplot(data=features_1, palette="Set3",linewidth=1)
sns.despine(left=True, bottom=True)

# %% [markdown]
# The dot in the heart of the violin is the mean of the given feature. Axis x represents the features so each violin refer to one feature, the width of each violin represents the distribution of correlations, on the y-axis.

# %%
plt.figure(figsize=(12, 5))
# Draw a violinplot with a narrower bandwidth than the default
sns.violinplot(data=StandardScaler().fit_transform(features_1), palette="Set3",linewidth=1)
sns.despine(left=True, bottom=True)

# %% [markdown]
# The following code plots a correlation matrix between all of the features.
# As the correlation value between two features gets higher it's background color gets darker.

# %%
cmap=sns.diverging_palette(180,280,s=80,l=50,n=7)
plt.figure(figsize=(25,25))
plt.title('Pearson correlation of features', y=1, size=18)
sns.heatmap(df.corr(),linewidths=0.4 ,vmax=1, center=0, square=True, 
            cmap=cmap, linecolor='white', annot=True);

# %% [markdown]
# From the correlation plot, we can see that some of the features display interesting correlation to one another, even if not very high. I list all the features which have positive correlation:
#
# - num.feature 17 and num.feature 29 have 0.59 correlation
# - num.feature 25 and num.feature 12 have 0.55 correlation
# - num.feature 17 and num.feature 7 have 0.50 correlation
#
# I also list all the features which have negative correlation:
# - num.feature 4 and num.feature 8 have -0.6 correlation
# - num.feature 12 and num.feature 8 have -0.52 correlation
# - num.feature 4 and num.feature 7 have -0.48 correlation
#
# The others are too close to 0...

# %%
plt.figure(figsize=(12,5))
plt.scatter(features_1[:, 16], features_1[:, 28])
plt.xlabel('Feature 17')
plt.ylabel('Feature 29');

# %%
plt.figure(figsize=(12,5))
plt.scatter(features_1[:, 3], features_1[:, 7])
plt.xlabel('Feature 25')
plt.ylabel('Feature 12');

# %% [markdown]
# I will do PCA later, for now a vital part of using PCA in practice is the ability to estimate how many components are needed to describe the data.
# This can be determined by looking at the cumulative explained variance ratio as a function of the number of components:

# %%
plt.figure(figsize=(12,5))
pca = PCA().fit(features_1)
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance');

# %% [markdown]
# This curve quantifies how much of the total variance is contained within the first N components. For example, we see that with our dataset the first 10 components capture more than 80% of the variance, while you need around 25 components to describe close to 100% of the variance.
#
# Here we see that our two-dimensional projection loses a lot of information (as measured by the explained variance) and that we'd need about 20 components to retain 90% of the variance.
#
# That would lead us to believe that using these 20 components, we would recover most of the essential characteristics of the data.

# %% [markdown]
# ## KNN

# %% [markdown]
# Training of KNN:

# %% [markdown]
# K has to be chosen first. I compute and plot the training and testing accuracy scores for a variety of different neighbor values. By observing how the accuracy scores differ for the training and testing sets with different values of k, I get an intuition for overfitting and underfitting.

# %%
# Setup arrays to store train and test accuracies
train_accuracy=[]
test_accuracy=[]

#try KNN with different k nearest neighbor from 1 to 30
neighbors=range(1,30)

#get data(train and test)
data=parse_data(n_components=0)

# Loop over different values of k
for k in neighbors:
    # Setup a k-NN Classifier with k neighbors: knn
    knn = KNeighborsClassifier(n_neighbors=k)
    # Fit the classifier to the training data
    knn.fit(*data.train())
    #Compute accuracy on the training set
    train_accuracy.append(knn.score(*data.train()))
    #Compute accuracy on the testing set
    test_accuracy.append(knn.score(*data.test()))
    
# Generate plot
plt.figure(figsize=(12,5))
plt.title('k-NN: Varying Number of Neighbors')
plt.plot(neighbors, test_accuracy, label='Test Accuracy')
plt.plot(neighbors, train_accuracy, label='Train Accuracy')
plt.xlabel('Number of Neighbors')
plt.ylabel('Accuracy')
plt.xticks(neighbors)
plt.legend()

#by looking at plot, best result accurs when n_neighbors is 16
print("Train Accuracy:", train_accuracy[15])
print("Test Accuracy:",test_accuracy[15])
# Out:
# normalized
# nc=30
# Train Accuracy: 0.696703296703
# Test Accuracy: 0.610256410256

# %% [markdown]
# By looking at the plot we notice that when we use one neighbor the model is too complex and overfits the training data. As more neighbors are considered, the training accuracy drops, yet the test accuracy increases, up to a point. Then it decreases and increases again up to 14. After about 16 neighbors, training accuracy starts to decrease while training oscillates.
# So, n_neighbors which give a good balance between the scores is 16.

# %%
def knn_in(normalize,n_components,samples=5,num_train=910,num_test=310,seed=49176,**knn_params):
    
    validation_scores=[]
    train_scores=[]
    
    for s in range(samples): #we extract 5 samples
        data = parse_data(num_train, num_test, seed+s,normalize,n_components) #seed+s means that we get different samples
        knn = KNeighborsClassifier(**knn_params)
        knn.fit(*data.train())
        train_score=knn.score(*data.train())
        validation_score=knn.score(*data.test())
        train_scores.append(train_score)
        validation_scores.append(validation_score)
        print("Training accuracy = %g, Validation accuracy = %g" % (train_score, validation_score))
    return knn

# %%
knn_0 = knn_in(n_neighbors = 16,normalize=False,n_components=0)
# Out:
# not normalized
# nc=30
# Training accuracy = 0.792308, Validation accuracy = 0.712903
# not normalized
# nc=30
# Training accuracy = 0.77033, Validation accuracy = 0.754839
# not normalized
# nc=30
# Training accuracy = 0.791209, Validation accuracy = 0.754839
# not normalized
# nc=30
# Training accuracy = 0.782418, Validation accuracy = 0.741935
# not normalized
# nc=30
# Training accuracy = 0.764835, Validation accuracy = 0.751613

# %%
knn_1 = knn_in(n_neighbors = 16,normalize=True, n_components=0.9) #normalization makes knn worse (?), pca instead is ok
# Out:
# normalized
# nc=17
# Training accuracy = 0.696703, Validation accuracy = 0.609677
# normalized
# nc=17
# Training accuracy = 0.697802, Validation accuracy = 0.6
# normalized
# nc=16
# Training accuracy = 0.696703, Validation accuracy = 0.629032
# normalized
# nc=17
# Training accuracy = 0.706593, Validation accuracy = 0.6
# normalized
# nc=17
# Training accuracy = 0.686813, Validation accuracy = 0.603226

# %%
from sklearn.model_selection import GridSearchCV

parameter_grid = {'weights': ['distance','uniform'],
                  'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
                 }
knn_0 = KNeighborsClassifier(n_neighbors=16)
grid_search = GridSearchCV(knn_0,param_grid=parameter_grid)

grid_search.fit(*data.train())
print('Best score: {}'.format(grid_search.best_score_)) 
print('Best parameters: {}'.format(grid_search.best_params_))
# Out:
# Best score: 0.5956043956043956
# Best parameters: {'algorithm': 'auto', 'weights': 'distance'}

# %%
knn_2 = knn_in(normalize=False,n_components=0.9,algorithm='auto',n_neighbors=16,weights='distance')
# Out:
# not normalized
# nc=17
# Training accuracy = 1, Validation accuracy = 0.729032
# not normalized
# nc=17
# Training accuracy = 1, Validation accuracy = 0.76129
# not normalized
# nc=16
# Training accuracy = 1, Validation accuracy = 0.783871
# not normalized
# nc=17
# Training accuracy = 1, Validation accuracy = 0.748387
# not normalized
# nc=17
# Training accuracy = 1, Validation accuracy = 0.767742

# %% [markdown]
# As we see there's no need to normalize dataset for KNN

# %% [markdown]
# We will use 8-K fold validation

# %%
model_k = KNeighborsClassifier(algorithm='auto',n_neighbors=16,weights='distance')

# %%
knn_cvscore=kfold(model=knn_0,n_splits=8,features=features_1,target=target)
# Out:
# Training score = 0.795075, Validation score = 0.742331
# Training score = 0.810026, Validation score = 0.662577
# Training score = 0.799472, Validation score = 0.760736
# Training score = 0.80387, Validation score = 0.760736
# Training score = 0.816344, Validation score = 0.796296
# Training score = 0.797891, Validation score = 0.771605
# Training score = 0.793497, Validation score = 0.765432
# Training score = 0.804921, Validation score = 0.765432
# CV accuracy = 0.753143

# %%
d['Knn'] = knn_cvscore

# %% [markdown]
# ## Random forest

# %% [markdown]
# Random forest is not affected by feature scaling, so we do not use normalized data.
# Also I found http://scikit-learn.org/stable/auto_examples/ensemble/plot_forest_importances.html
# Using a random forest we can measure feature importance as the averaged impurity decrease computed from all decision trees in the forest.

# %%
def random_f(num_train=910,num_test=390,n_components=0,normalize=False,feat_imp=True,**xtrees_params):
    
    data=parse_data(num_train, num_test, n_components,normalize)
    
    clf=ExtraTreesClassifier(**xtrees_params)
    clf.fit(*data.train())
    train_score=clf.score(*data.train())
    test_score=clf.score(*data.test())
    print("Final training score = %g, validation score = %g" % (train_score, test_score))
    
    if feat_imp:
        imp = clf.feature_importances_
        std = np.std([tree.feature_importances_ for tree in clf.estimators_],axis=0)
        indices = np.argsort(imp)[::-1]
        print("Feature ranking:")
        fe, ta = data.train()
        for f in range(fe.shape[1]):
            print("%d. feature %d (%f)" % (f + 1, indices[f]+1, imp[indices[f]]))
        
        # Plot the feature importances of the forest
        plt.figure(figsize = (12,5))    
        plt.title("Feature importances")
        plt.bar(range(fe.shape[1]), imp[indices], color='b', align="center")
        plt.xticks(range(fe.shape[1]), indices + 1)
        plt.xlim([-1, fe.shape[1]])
        
        plt.show()
        return train_score, test_score
    
    return clf

# %%
clf = random_f()
# Out:
# not normalized
# nc=17
# Final training score = 1, validation score = 0.584615
# Feature ranking:
# 1. feature 28 (0.067346)
# 2. feature 12 (0.066510)
# 3. feature 23 (0.058902)
# 4. feature 8 (0.051185)
# 5. feature 19 (0.049150)
# 6. feature 25 (0.044314)
# 7. feature 3 (0.044014)
# 8. feature 4 (0.043861)
# 9. feature 17 (0.038776)
# 10. feature 5 (0.038558)
# 11. feature 7 (0.038198)
# 12. feature 13 (0.037465)
# 13. feature 29 (0.034815)
# 14. feature 26 (0.028002)
# 15. feature 18 (0.027428)
# 16. feature 11 (0.026519)
# 17. feature 21 (0.025018)
# 18. feature 10 (0.024288)
# 19. feature 24 (0.023905)
# 20. feature 6 (0.022643)
# 21. feature 16 (0.022626)
# 22. feature 20 (0.022560)
# 23. feature 27 (0.022163)
# 24. feature 2 (0.022084)
# 25. feature 30 (0.021895)
# 26. feature 9 (0.021367)
# 27. feature 22 (0.020568)
# 28. feature 1 (0.019889)
# 29. feature 15 (0.019189)
# 30. feature 14 (0.016762)

# %% [markdown]
# There might be something interesting about num.features 28 and 12, however I don't know if their importances are high enough

# %%
data = parse_data(n_components=0, normalize=False)

t_scores_xt = []
v_scores_xt = []

max_dep = range(1,20)

for md in max_dep:
    tree = ExtraTreesClassifier(max_depth=md,random_state=0)
    tree.fit(*data.train())
    t_score_xt=tree.score(*data.train())
    v_score_xt=tree.score(*data.test())
    print("mdepth=%g,training score = %g, validation score = %g" % (md,t_score_xt, v_score_xt))

    t_scores_xt.append(t_score_xt)
    v_scores_xt.append(v_score_xt)

plt.figure(figsize = (12,5))    
plt.plot(max_dep,t_scores_xt, label='Accuracy of the training set')
plt.plot(max_dep,v_scores_xt, label='Accuracy of the test set')
plt.ylabel('Accuracy')
plt.xlabel('Max Depth')
plt.xticks(max_dep)
plt.legend();

# By having larger max_depth (>5), we overfit the model into training data, so the accuracy for training set become 
# but the accuracy for test set decrease

# other parameters than can work with:
# - min_samples_leaf, max_sample_leaf
# - max_leaf_node
# Out:
# not normalized
# nc=30
# mdepth=1,training score = 0.357143, validation score = 0.328205
# mdepth=2,training score = 0.463736, validation score = 0.412821
# mdepth=3,training score = 0.561538, validation score = 0.502564
# mdepth=4,training score = 0.592308, validation score = 0.512821
# mdepth=5,training score = 0.654945, validation score = 0.548718
# mdepth=6,training score = 0.697802, validation score = 0.546154
# mdepth=7,training score = 0.782418, validation score = 0.55641
# mdepth=8,training score = 0.854945, validation score = 0.623077
# mdepth=9,training score = 0.910989, validation score = 0.594872
# mdepth=10,training score = 0.957143, validation score = 0.615385
# mdepth=11,training score = 0.98022, validation score = 0.664103
# mdepth=12,training score = 0.992308, validation score = 0.617949
# mdepth=13,training score = 0.997802, validation score = 0.612821
# mdepth=14,training score = 1, validation score = 0.594872
# mdepth=15,training score = 1, validation score = 0.628205
# mdepth=16,training score = 1, validation score = 0.612821
# mdepth=17,training score = 1, validation score = 0.641026
# mdepth=18,training score = 1, validation score = 0.635897
# mdepth=19,training score = 1, validation score = 0.602564

# %% [markdown]
# by looking at plot, best result accurs when max_depth is 11, after that value the model becomes too complex and it overfits.

# %%
data = parse_data(num_train=910, num_test=390, seed=49176, normalize=False, n_components=0)
xtrees = ExtraTreesClassifier()

n_estimators = range(1,50)
train_scores_9 = []
validation_scores_9 = []
#we can iterate over trees so as to check accuracy
for n in n_estimators:      
    xtrees.set_params(max_depth=11, n_estimators = n)
    xtrees.fit(*data.train())
    validation_score_9 = xtrees.score(*data.test())
    train_score_9 = xtrees.score(*data.train())
    print("estimators = %g, Test score = %g, Validation score = %g" % (n,train_score_9, validation_score_9))
          
    train_scores_9.append(train_score_9)
    validation_scores_9.append(validation_score_9)

plt.figure(figsize = (12,5))    
plt.plot(train_scores_9, alpha=0.8, label='Train')
plt.plot(validation_scores_9, alpha=0.8, label='Test')
plt.title("Accuracy as number of estimators increases", fontsize=14)
plt.xlabel('number of estimators')
plt.legend(loc = 'upper left');
# Out:
# not normalized
# nc=30
# estimators = 1, Test score = 0.604396, Validation score = 0.428205
# estimators = 2, Test score = 0.814286, Validation score = 0.397436
# estimators = 3, Test score = 0.935165, Validation score = 0.479487
# estimators = 4, Test score = 0.908791, Validation score = 0.525641
# estimators = 5, Test score = 0.940659, Validation score = 0.553846
# estimators = 6, Test score = 0.972527, Validation score = 0.546154
# estimators = 7, Test score = 0.969231, Validation score = 0.512821
# estimators = 8, Test score = 0.984615, Validation score = 0.564103
# estimators = 9, Test score = 0.984615, Validation score = 0.592308
# estimators = 10, Test score = 0.971429, Validation score = 0.605128
# estimators = 11, Test score = 0.981319, Validation score = 0.630769
# estimators = 12, Test score = 0.974725, Validation score = 0.584615
# estimators = 13, Test score = 0.971429, Validation score = 0.576923
# estimators = 14, Test score = 0.992308, Validation score = 0.658974
# estimators = 15, Test score = 0.992308, Validation score = 0.605128
# estimators = 16, Test score = 0.986813, Validation score = 0.615385
# estimators = 17, Test score = 0.989011, Validation score = 0.648718
# estimators = 18, Test score = 0.992308, Validation score = 0.648718
# estimators = 19, Test score = 0.996703, Validation score = 0.664103
# estimators = 20, Test score = 0.993407, Validation score = 0.648718
# estimators = 21, Test score = 0.985714, Validation score = 0.684615
# estimators = 22, Test score = 0.992308, Validation score = 0.676923
# estimators = 23, Test score = 0.996703, Validation score = 0.684615
# estimators = 24, Test score = 0.996703, Validation score = 0.669231
# estimators = 25, Test score = 0.993407, Validation score = 0.661538
# estimators = 26, Test score = 0.99011, Validation score = 0.658974
# estimators = 27, Test score = 0.997802, Validation score = 0.676923
# estimators = 28, Test score = 0.994505, Validation score = 0.697436
# estimators = 29, Test score = 0.993407, Validation score = 0.705128
# estimators = 30, Test score = 0.996703, Validation score = 0.705128
# estimators = 31, Test score = 0.994505, Validation score = 0.674359
# estimators = 32, Test score = 0.994505, Validation score = 0.710256
# estimators = 33, Test score = 0.996703, Validation score = 0.679487
# estimators = 34, Test score = 0.994505, Validation score = 0.682051
# estimators = 35, Test score = 0.995604, Validation score = 0.697436
# estimators = 36, Test score = 0.994505, Validation score = 0.676923
# estimators = 37, Test score = 0.996703, Validation score = 0.687179
# estimators = 38, Test score = 0.992308, Validation score = 0.717949
# estimators = 39, Test score = 0.991209, Validation score = 0.682051
# estimators = 40, Test score = 0.997802, Validation score = 0.707692
# estimators = 41, Test score = 0.992308, Validation score = 0.7
# estimators = 42, Test score = 0.997802, Validation score = 0.687179
# estimators = 43, Test score = 0.996703, Validation score = 0.697436
# estimators = 44, Test score = 0.994505, Validation score = 0.676923
# estimators = 45, Test score = 0.996703, Validation score = 0.676923
# estimators = 46, Test score = 0.995604, Validation score = 0.705128
# estimators = 47, Test score = 0.996703, Validation score = 0.692308
# estimators = 48, Test score = 0.996703, Validation score = 0.697436
# estimators = 49, Test score = 0.997802, Validation score = 0.687179

# %% [markdown]
# by looking at the graph I decide to use n_estimator=38

# %%
data = parse_data(num_train=910, num_test = 390, seed = 49176, normalize = False, n_components = 0)

jobs = range(1,30)
    
train_scores = []
validation_scores = []
#we can iterate over different levels of depth so as to check accuracy
for j in jobs:
    xtrees = ExtraTreesClassifier(max_depth=11,n_estimators=38,n_jobs=j)
    xtrees.fit(*data.train())
    validation_score_0 = xtrees.score(*data.test())
    train_score_0 = xtrees.score(*data.train())
    print("Tree = %g, Test score = %g, Validation score = %g" % (j,train_score_0, validation_score_0))

    train_scores.append(train_score_0)
    validation_scores.append(validation_score_0)
    
plt.figure(figsize=(12,5))        
plt.plot(train_scores, label='Train')
plt.plot(validation_scores, label='Test')
plt.title("Accuracy as n_jobs increases", fontsize=14)
plt.xlabel('N of jobs')
plt.xticks(jobs)
plt.legend(loc = 'upper left');
# Out:
# not normalized
# nc=30
# Tree = 1, Test score = 0.998901, Validation score = 0.666667
# Tree = 2, Test score = 0.994505, Validation score = 0.684615
# Tree = 3, Test score = 0.994505, Validation score = 0.651282
# Tree = 4, Test score = 0.995604, Validation score = 0.666667
# Tree = 5, Test score = 0.997802, Validation score = 0.707692
# Tree = 6, Test score = 0.997802, Validation score = 0.689744
# Tree = 7, Test score = 0.996703, Validation score = 0.702564
# Tree = 8, Test score = 0.996703, Validation score = 0.702564
# Tree = 9, Test score = 0.992308, Validation score = 0.692308
# Tree = 10, Test score = 1, Validation score = 0.702564
# Tree = 11, Test score = 0.995604, Validation score = 0.710256
# Tree = 12, Test score = 0.996703, Validation score = 0.7
# Tree = 13, Test score = 0.992308, Validation score = 0.679487
# Tree = 14, Test score = 0.994505, Validation score = 0.715385
# Tree = 15, Test score = 0.996703, Validation score = 0.676923
# Tree = 16, Test score = 0.996703, Validation score = 0.692308
# Tree = 17, Test score = 0.995604, Validation score = 0.682051
# Tree = 18, Test score = 0.996703, Validation score = 0.684615
# Tree = 19, Test score = 0.994505, Validation score = 0.710256
# Tree = 20, Test score = 0.991209, Validation score = 0.715385
# Tree = 21, Test score = 0.996703, Validation score = 0.7
# Tree = 22, Test score = 0.995604, Validation score = 0.723077
# Tree = 23, Test score = 0.993407, Validation score = 0.7
# Tree = 24, Test score = 1, Validation score = 0.679487
# Tree = 25, Test score = 0.992308, Validation score = 0.671795
# Tree = 26, Test score = 0.995604, Validation score = 0.664103
# Tree = 27, Test score = 0.995604, Validation score = 0.658974
# Tree = 28, Test score = 0.993407, Validation score = 0.7
# Tree = 29, Test score = 0.993407, Validation score = 0.674359

# %% [markdown]
# By looking at the graph I choose 22 jobs

# %% [markdown]
# I could try to tune every parameter, however for sklearn.tree.ExtraTreeClassifier the parameters are too many:
# max_features, min_samples_split, min_samples_leaf, min_weight_fraction_leaf, max_leaf_nodes, min_impurity_split,min_impurity_decrease
#
# My method is slow and is not efficient, I can't go over each parameter. I could contintue using sklearn.model_selection.GridSearchCV

# %%
data = parse_data(num_train=910, num_test=390, n_components=0, seed=49176)
params ={'max_leaf_nodes':[random.randint(1,80) for k in range(20)], 
         'min_samples_leaf':[random.randint(1,80) for k in range(20)],
        }

model_000 = ExtraTreesClassifier(criterion='entropy',max_depth=11,n_estimators=38,n_jobs=22)
n_search_iter = 5
gCV_0 = RandomizedSearchCV(estimator = model_000, n_iter = n_search_iter, param_distributions = params, cv =8)

gCV_0.fit(*data.train())
    
# evaluate the best randomized searched model on the testing data
print('accuracy:', gCV_0.score(*data.test()))
print('best parameters:', gCV_0.best_params_)
# Out:
# normalized
# nc=30
# accuracy: 0.54358974359
# best parameters: {'min_samples_leaf': 27, 'max_leaf_nodes': 69}

# %%
xtrees = ExtraTreesClassifier(criterion='entropy', #I choose to use information gain to measure quality of the split                              n_estimators=28, 
                              max_depth=11, 
                              n_jobs=22,
                              min_samples_leaf=3,
                              max_leaf_nodes=75,
                              n_estimators=38
                             )

# %%
xtr_cvscore = kfold(model = xtrees, n_splits=8,features=features_1,target=target)
# Out:
# Training score = 0.901495, Validation score = 0.674847
# Training score = 0.91117, Validation score = 0.619632
# Training score = 0.912929, Validation score = 0.736196
# Training score = 0.913808, Validation score = 0.754601
# Training score = 0.920914, Validation score = 0.765432
# Training score = 0.91652, Validation score = 0.722222
# Training score = 0.912127, Validation score = 0.691358
# Training score = 0.91652, Validation score = 0.722222
# CV accuracy = 0.710814

# %%
d['Random Forest'] = xtr_cvscore

# %% [markdown]
# ## MLP

# %%
def mlperc(num_train = 910, num_test = 390, seed = 49176, normalize = True, n_components = 0, **mlp_params):
    
    data = parse_data(num_train, num_test, seed, normalize, n_components)
    mlp = MLPClassifier(**mlp_params)
    max_iter = mlp_params.pop('max_iter')
    
    train_scores = []
    validation_scores = []
   
    for epoch in range(max_iter):      
        mlp.set_params(max_iter = epoch + 1)
        mlp.fit(*data.train())
        train_score = mlp.score(*data.train())
        validation_score = mlp.score(*data.test())
        loss = mlp.loss_
        
        print("Epoch = %g, Loss = %g, Training score = %g, Validation score = %g" % (epoch, loss, train_score, validation_score))
        
        train_scores.append(train_score)
        validation_scores.append(validation_score)
        mlp.set_params(warm_start = True) #if we fit at the second time, do we start from the last fit?
    
    plt.figure(figsize=(12,5))
    plt.plot(train_scores, alpha=0.8, label='Train')
    plt.plot(validation_scores, color = 'magenta', alpha=0.8, label='Test')
    plt.title("Accuracy over epochs", fontsize=14)
    plt.xlabel('Epochs')
    plt.legend(loc = 'upper left')
    plt.show()
    
    # Predicting the Test set results
    preds = mlp.predict(data.test()[0])
    mlp_matrix = confusion_matrix(data.test()[1], preds)
    classes=[0,1,2,3,4]
    plot_confusion_matrix(mlp_matrix, classes)
    return mlp

# %%
mlperc(max_iter = 200,normalize=False) #not normalized
# Out:
# not normalized
# nc=30
# Epoch = 0, Loss = 1.98726, Training score = 0.293407, Validation score = 0.261538
# Epoch = 1, Loss = 1.74413, Training score = 0.342857, Validation score = 0.330769
# Epoch = 2, Loss = 1.56928, Training score = 0.386813, Validation score = 0.361538
# Epoch = 3, Loss = 1.43298, Training score = 0.432967, Validation score = 0.428205
# Epoch = 4, Loss = 1.32772, Training score = 0.501099, Validation score = 0.474359
# Epoch = 5, Loss = 1.2439, Training score = 0.532967, Validation score = 0.507692
# Epoch = 6, Loss = 1.1759, Training score = 0.569231, Validation score = 0.528205
# Epoch = 7, Loss = 1.1176, Training score = 0.598901, Validation score = 0.535897
# Epoch = 8, Loss = 1.06765, Training score = 0.625275, Validation score = 0.569231
# Epoch = 9, Loss = 1.02609, Training score = 0.647253, Validation score = 0.579487
# Epoch = 10, Loss = 0.989202, Training score = 0.659341, Validation score = 0.592308
# C:\Users\a_mon\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Epoch = 11, Loss = 0.957137, Training score = 0.671429, Validation score = 0.602564
# Epoch = 12, Loss = 0.928179, Training score = 0.683516, Validation score = 0.612821
# Epoch = 13, Loss = 0.901842, Training score = 0.693407, Validation score = 0.620513
# Epoch = 14, Loss = 0.879609, Training score = 0.706593, Validation score = 0.641026
# Epoch = 15, Loss = 0.857634, Training score = 0.717582, Validation score = 0.651282
# Epoch = 16, Loss = 0.837889, Training score = 0.721978, Validation score = 0.651282
# Epoch = 17, Loss = 0.819622, Training score = 0.735165, Validation score = 0.65641
# Epoch = 18, Loss = 0.802557, Training score = 0.73956, Validation score = 0.664103
# Epoch = 19, Loss = 0.785918, Training score = 0.745055, Validation score = 0.661538
# Epoch = 20, Loss = 0.770346, Training score = 0.749451, Validation score = 0.666667
# Epoch = 21, Loss = 0.755608, Training score = 0.762637, Validation score = 0.671795
# Epoch = 22, Loss = 0.742099, Training score = 0.77033, Validation score = 0.671795
# Epoch = 23, Loss = 0.728265, Training score = 0.771429, Validation score = 0.679487
# Epoch = 24, Loss = 0.715518, Training score = 0.773626, Validation score = 0.682051
# Epoch = 25, Loss = 0.703294, Training score = 0.775824, Validation score = 0.689744
# Epoch = 26, Loss = 0.691393, Training score = 0.782418, Validation score = 0.694872
# Epoch = 27, Loss = 0.679672, Training score = 0.787912, Validation score = 0.697436
# Epoch = 28, Loss = 0.668301, Training score = 0.792308, Validation score = 0.710256
# Epoch = 29, Loss = 0.65759, Training score = 0.795604, Validation score = 0.712821
# Epoch = 30, Loss = 0.647028, Training score = 0.8, Validation score = 0.717949
# Epoch = 31, Loss = 0.636612, Training score = 0.801099, Validation score = 0.723077
# Epoch = 32, Loss = 0.626833, Training score = 0.803297, Validation score = 0.728205
# Epoch = 33, Loss = 0.616931, Training score = 0.808791, Validation score = 0.730769
# Epoch = 34, Loss = 0.607644, Training score = 0.812088, Validation score = 0.730769
# Epoch = 35, Loss = 0.59834, Training score = 0.816484, Validation score = 0.728205
# Epoch = 36, Loss = 0.589553, Training score = 0.817582, Validation score = 0.730769
# Epoch = 37, Loss = 0.580329, Training score = 0.81978, Validation score = 0.730769
# Epoch = 38, Loss = 0.571827, Training score = 0.825275, Validation score = 0.730769
# Epoch = 39, Loss = 0.563604, Training score = 0.826374, Validation score = 0.725641
# Epoch = 40, Loss = 0.555497, Training score = 0.828571, Validation score = 0.728205
# Epoch = 41, Loss = 0.547286, Training score = 0.834066, Validation score = 0.728205
# Epoch = 42, Loss = 0.539363, Training score = 0.83956, Validation score = 0.733333
# Epoch = 43, Loss = 0.531517, Training score = 0.840659, Validation score = 0.741026
# Epoch = 44, Loss = 0.523857, Training score = 0.843956, Validation score = 0.741026
# Epoch = 45, Loss = 0.516576, Training score = 0.845055, Validation score = 0.738462
# Epoch = 46, Loss = 0.508836, Training score = 0.851648, Validation score = 0.751282
# Epoch = 47, Loss = 0.501918, Training score = 0.851648, Validation score = 0.74359
# Epoch = 48, Loss = 0.494503, Training score = 0.857143, Validation score = 0.74359
# Epoch = 49, Loss = 0.487705, Training score = 0.858242, Validation score = 0.748718
# Epoch = 50, Loss = 0.480537, Training score = 0.859341, Validation score = 0.748718
# Epoch = 51, Loss = 0.474097, Training score = 0.864835, Validation score = 0.746154
# Epoch = 52, Loss = 0.467265, Training score = 0.869231, Validation score = 0.751282
# Epoch = 53, Loss = 0.460449, Training score = 0.87033, Validation score = 0.751282
# Epoch = 54, Loss = 0.454457, Training score = 0.879121, Validation score = 0.751282
# Epoch = 55, Loss = 0.448007, Training score = 0.88022, Validation score = 0.753846
# Epoch = 56, Loss = 0.44206, Training score = 0.881319, Validation score = 0.748718
# Epoch = 57, Loss = 0.436214, Training score = 0.883516, Validation score = 0.748718
# Epoch = 58, Loss = 0.430088, Training score = 0.882418, Validation score = 0.751282
# Epoch = 59, Loss = 0.424209, Training score = 0.885714, Validation score = 0.751282
# Epoch = 60, Loss = 0.418705, Training score = 0.886813, Validation score = 0.748718
# Epoch = 61, Loss = 0.412763, Training score = 0.892308, Validation score = 0.753846
# Epoch = 62, Loss = 0.406904, Training score = 0.892308, Validation score = 0.751282
# Epoch = 63, Loss = 0.401716, Training score = 0.898901, Validation score = 0.748718
# Epoch = 64, Loss = 0.39622, Training score = 0.897802, Validation score = 0.751282
# Epoch = 65, Loss = 0.391135, Training score = 0.9, Validation score = 0.758974
# Epoch = 66, Loss = 0.385516, Training score = 0.902198, Validation score = 0.758974
# Epoch = 67, Loss = 0.380247, Training score = 0.903297, Validation score = 0.761538
# Epoch = 68, Loss = 0.375457, Training score = 0.906593, Validation score = 0.758974
# Epoch = 69, Loss = 0.370424, Training score = 0.90989, Validation score = 0.748718
# Epoch = 70, Loss = 0.365308, Training score = 0.912088, Validation score = 0.748718
# Epoch = 71, Loss = 0.360371, Training score = 0.912088, Validation score = 0.753846
# Epoch = 72, Loss = 0.355359, Training score = 0.914286, Validation score = 0.751282
# Epoch = 73, Loss = 0.350252, Training score = 0.917582, Validation score = 0.751282
# Epoch = 74, Loss = 0.345722, Training score = 0.918681, Validation score = 0.751282
# Epoch = 75, Loss = 0.340943, Training score = 0.920879, Validation score = 0.753846
# Epoch = 76, Loss = 0.336411, Training score = 0.920879, Validation score = 0.753846
# Epoch = 77, Loss = 0.331819, Training score = 0.923077, Validation score = 0.753846
# Epoch = 78, Loss = 0.327466, Training score = 0.927473, Validation score = 0.751282
# Epoch = 79, Loss = 0.322935, Training score = 0.928571, Validation score = 0.753846
# Epoch = 80, Loss = 0.318942, Training score = 0.928571, Validation score = 0.753846
# Epoch = 81, Loss = 0.314749, Training score = 0.92967, Validation score = 0.753846
# Epoch = 82, Loss = 0.310277, Training score = 0.931868, Validation score = 0.75641
# Epoch = 83, Loss = 0.305952, Training score = 0.935165, Validation score = 0.75641
# Epoch = 84, Loss = 0.302156, Training score = 0.935165, Validation score = 0.75641
# Epoch = 85, Loss = 0.298156, Training score = 0.934066, Validation score = 0.75641
# Epoch = 86, Loss = 0.294296, Training score = 0.937363, Validation score = 0.753846
# Epoch = 87, Loss = 0.290462, Training score = 0.937363, Validation score = 0.75641
# Epoch = 88, Loss = 0.286757, Training score = 0.940659, Validation score = 0.764103
# Epoch = 89, Loss = 0.282724, Training score = 0.942857, Validation score = 0.761538
# Epoch = 90, Loss = 0.278854, Training score = 0.942857, Validation score = 0.764103
# Epoch = 91, Loss = 0.275311, Training score = 0.943956, Validation score = 0.761538
# Epoch = 92, Loss = 0.271632, Training score = 0.942857, Validation score = 0.761538
# Epoch = 93, Loss = 0.267756, Training score = 0.945055, Validation score = 0.764103
# Epoch = 94, Loss = 0.26413, Training score = 0.943956, Validation score = 0.766667
# Epoch = 95, Loss = 0.260511, Training score = 0.948352, Validation score = 0.764103
# Epoch = 96, Loss = 0.257262, Training score = 0.948352, Validation score = 0.764103
# Epoch = 97, Loss = 0.253851, Training score = 0.950549, Validation score = 0.769231
# Epoch = 98, Loss = 0.250518, Training score = 0.949451, Validation score = 0.769231
# Epoch = 99, Loss = 0.246901, Training score = 0.956044, Validation score = 0.764103
# Epoch = 100, Loss = 0.244089, Training score = 0.956044, Validation score = 0.766667
# Epoch = 101, Loss = 0.240723, Training score = 0.953846, Validation score = 0.769231
# Epoch = 102, Loss = 0.237517, Training score = 0.953846, Validation score = 0.766667
# Epoch = 103, Loss = 0.234335, Training score = 0.954945, Validation score = 0.764103
# Epoch = 104, Loss = 0.231203, Training score = 0.956044, Validation score = 0.761538
# Epoch = 105, Loss = 0.228181, Training score = 0.96044, Validation score = 0.764103
# Epoch = 106, Loss = 0.225159, Training score = 0.961538, Validation score = 0.761538
# Epoch = 107, Loss = 0.222058, Training score = 0.962637, Validation score = 0.758974
# Epoch = 108, Loss = 0.218966, Training score = 0.963736, Validation score = 0.761538
# Epoch = 109, Loss = 0.216137, Training score = 0.964835, Validation score = 0.761538
# Epoch = 110, Loss = 0.213349, Training score = 0.964835, Validation score = 0.764103
# Epoch = 111, Loss = 0.210416, Training score = 0.967033, Validation score = 0.761538
# Epoch = 112, Loss = 0.207913, Training score = 0.965934, Validation score = 0.761538
# Epoch = 113, Loss = 0.205186, Training score = 0.967033, Validation score = 0.758974
# Epoch = 114, Loss = 0.202276, Training score = 0.971429, Validation score = 0.75641
# Epoch = 115, Loss = 0.199735, Training score = 0.972527, Validation score = 0.769231
# Epoch = 116, Loss = 0.196911, Training score = 0.972527, Validation score = 0.764103
# Epoch = 117, Loss = 0.194503, Training score = 0.97033, Validation score = 0.766667
# Epoch = 118, Loss = 0.191615, Training score = 0.972527, Validation score = 0.769231
# Epoch = 119, Loss = 0.18899, Training score = 0.974725, Validation score = 0.769231
# Epoch = 120, Loss = 0.186679, Training score = 0.978022, Validation score = 0.766667
# Epoch = 121, Loss = 0.183999, Training score = 0.976923, Validation score = 0.766667
# Epoch = 122, Loss = 0.181748, Training score = 0.979121, Validation score = 0.761538
# Epoch = 123, Loss = 0.179063, Training score = 0.98022, Validation score = 0.758974
# Epoch = 124, Loss = 0.176686, Training score = 0.98022, Validation score = 0.758974
# Epoch = 125, Loss = 0.174285, Training score = 0.98022, Validation score = 0.75641
# Epoch = 126, Loss = 0.172291, Training score = 0.981319, Validation score = 0.751282
# Epoch = 127, Loss = 0.169664, Training score = 0.981319, Validation score = 0.758974
# Epoch = 128, Loss = 0.167464, Training score = 0.982418, Validation score = 0.75641
# Epoch = 129, Loss = 0.165034, Training score = 0.982418, Validation score = 0.75641
# Epoch = 130, Loss = 0.162915, Training score = 0.982418, Validation score = 0.764103
# Epoch = 131, Loss = 0.16066, Training score = 0.982418, Validation score = 0.764103
# Epoch = 132, Loss = 0.158595, Training score = 0.982418, Validation score = 0.75641
# Epoch = 133, Loss = 0.156426, Training score = 0.983516, Validation score = 0.75641
# Epoch = 134, Loss = 0.154196, Training score = 0.984615, Validation score = 0.758974
# Epoch = 135, Loss = 0.152052, Training score = 0.984615, Validation score = 0.758974
# Epoch = 136, Loss = 0.150259, Training score = 0.984615, Validation score = 0.761538
# Epoch = 137, Loss = 0.148287, Training score = 0.985714, Validation score = 0.761538
# Epoch = 138, Loss = 0.146193, Training score = 0.985714, Validation score = 0.761538
# Epoch = 139, Loss = 0.144215, Training score = 0.985714, Validation score = 0.761538
# Epoch = 140, Loss = 0.142306, Training score = 0.985714, Validation score = 0.758974
# Epoch = 141, Loss = 0.140447, Training score = 0.985714, Validation score = 0.75641
# Epoch = 142, Loss = 0.138505, Training score = 0.986813, Validation score = 0.758974
# Epoch = 143, Loss = 0.136685, Training score = 0.987912, Validation score = 0.761538
# Epoch = 144, Loss = 0.134984, Training score = 0.987912, Validation score = 0.758974
# Epoch = 145, Loss = 0.133062, Training score = 0.986813, Validation score = 0.764103
# Epoch = 146, Loss = 0.131458, Training score = 0.987912, Validation score = 0.764103
# Epoch = 147, Loss = 0.129573, Training score = 0.986813, Validation score = 0.764103
# Epoch = 148, Loss = 0.127902, Training score = 0.99011, Validation score = 0.766667
# Epoch = 149, Loss = 0.126245, Training score = 0.99011, Validation score = 0.758974
# Epoch = 150, Loss = 0.124583, Training score = 0.99011, Validation score = 0.758974
# Epoch = 151, Loss = 0.122949, Training score = 0.991209, Validation score = 0.753846
# Epoch = 152, Loss = 0.121269, Training score = 0.992308, Validation score = 0.75641
# Epoch = 153, Loss = 0.119853, Training score = 0.992308, Validation score = 0.758974
# Epoch = 154, Loss = 0.118205, Training score = 0.992308, Validation score = 0.75641
# Epoch = 155, Loss = 0.116702, Training score = 0.992308, Validation score = 0.75641
# Epoch = 156, Loss = 0.115136, Training score = 0.992308, Validation score = 0.753846
# Epoch = 157, Loss = 0.113505, Training score = 0.992308, Validation score = 0.75641
# Epoch = 158, Loss = 0.11215, Training score = 0.991209, Validation score = 0.75641
# Epoch = 159, Loss = 0.110727, Training score = 0.992308, Validation score = 0.75641
# Epoch = 160, Loss = 0.10927, Training score = 0.993407, Validation score = 0.758974
# Epoch = 161, Loss = 0.1078, Training score = 0.993407, Validation score = 0.758974
# Epoch = 162, Loss = 0.106468, Training score = 0.993407, Validation score = 0.758974
# Epoch = 163, Loss = 0.105133, Training score = 0.993407, Validation score = 0.758974
# Epoch = 164, Loss = 0.103844, Training score = 0.993407, Validation score = 0.75641
# Epoch = 165, Loss = 0.102344, Training score = 0.994505, Validation score = 0.75641
# Epoch = 166, Loss = 0.101067, Training score = 0.994505, Validation score = 0.75641
# Epoch = 167, Loss = 0.0997912, Training score = 0.994505, Validation score = 0.75641
# Epoch = 168, Loss = 0.0985457, Training score = 0.994505, Validation score = 0.751282
# Epoch = 169, Loss = 0.0972954, Training score = 0.994505, Validation score = 0.751282
# Epoch = 170, Loss = 0.0961419, Training score = 0.994505, Validation score = 0.751282
# Epoch = 171, Loss = 0.0948936, Training score = 0.994505, Validation score = 0.751282
# Epoch = 172, Loss = 0.0936591, Training score = 0.994505, Validation score = 0.751282
# Epoch = 173, Loss = 0.0925084, Training score = 0.994505, Validation score = 0.751282
# Epoch = 174, Loss = 0.0914435, Training score = 0.994505, Validation score = 0.751282
# Epoch = 175, Loss = 0.0902414, Training score = 0.995604, Validation score = 0.751282
# Epoch = 176, Loss = 0.089033, Training score = 0.995604, Validation score = 0.751282
# Epoch = 177, Loss = 0.0880386, Training score = 0.997802, Validation score = 0.751282
# Epoch = 178, Loss = 0.086959, Training score = 0.996703, Validation score = 0.751282
# Epoch = 179, Loss = 0.0857993, Training score = 0.996703, Validation score = 0.751282
# Epoch = 180, Loss = 0.0847389, Training score = 0.996703, Validation score = 0.751282
# Epoch = 181, Loss = 0.0836947, Training score = 0.994505, Validation score = 0.751282
# Epoch = 182, Loss = 0.0826166, Training score = 0.997802, Validation score = 0.751282
# Epoch = 183, Loss = 0.0816872, Training score = 0.998901, Validation score = 0.751282
# Epoch = 184, Loss = 0.0806443, Training score = 0.998901, Validation score = 0.748718
# Epoch = 185, Loss = 0.079627, Training score = 0.998901, Validation score = 0.751282
# Epoch = 186, Loss = 0.078716, Training score = 0.997802, Validation score = 0.751282
# Epoch = 187, Loss = 0.0778605, Training score = 0.998901, Validation score = 0.751282
# Epoch = 188, Loss = 0.0768247, Training score = 0.998901, Validation score = 0.751282
# Epoch = 189, Loss = 0.075836, Training score = 0.998901, Validation score = 0.751282
# Epoch = 190, Loss = 0.0750477, Training score = 0.998901, Validation score = 0.751282
# Epoch = 191, Loss = 0.0741065, Training score = 0.998901, Validation score = 0.748718
# Epoch = 192, Loss = 0.0732507, Training score = 0.998901, Validation score = 0.748718
# Epoch = 193, Loss = 0.0724011, Training score = 0.998901, Validation score = 0.748718
# Epoch = 194, Loss = 0.0714585, Training score = 0.998901, Validation score = 0.748718
# Epoch = 195, Loss = 0.0706252, Training score = 0.998901, Validation score = 0.748718
# Epoch = 196, Loss = 0.0697741, Training score = 1, Validation score = 0.748718
# Epoch = 197, Loss = 0.0689899, Training score = 1, Validation score = 0.751282
# Epoch = 198, Loss = 0.0681442, Training score = 1, Validation score = 0.751282
# Epoch = 199, Loss = 0.0673079, Training score = 1, Validation score = 0.751282
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=True)

# %%
mlperc(max_iter = 130,normalize=True) #mlp works better with normalized data, but if we look at the confusion matrix it's even worse
# Out:
# normalized
# nc=30
# Epoch = 0, Loss = 1.73857, Training score = 0.262637, Validation score = 0.235897
# Epoch = 1, Loss = 1.63689, Training score = 0.315385, Validation score = 0.248718
# Epoch = 2, Loss = 1.55555, Training score = 0.352747, Validation score = 0.289744
# Epoch = 3, Loss = 1.48388, Training score = 0.389011, Validation score = 0.34359
# Epoch = 4, Loss = 1.42199, Training score = 0.432967, Validation score = 0.369231
# Epoch = 5, Loss = 1.36797, Training score = 0.473626, Validation score = 0.412821
# Epoch = 6, Loss = 1.31936, Training score = 0.502198, Validation score = 0.446154
# Epoch = 7, Loss = 1.27491, Training score = 0.536264, Validation score = 0.464103
# Epoch = 8, Loss = 1.23435, Training score = 0.553846, Validation score = 0.476923
# Epoch = 9, Loss = 1.19855, Training score = 0.576923, Validation score = 0.505128
# Epoch = 10, Loss = 1.16468, Training score = 0.592308, Validation score = 0.517949
# C:\Users\a_mon\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Epoch = 11, Loss = 1.13488, Training score = 0.604396, Validation score = 0.528205
# Epoch = 12, Loss = 1.1064, Training score = 0.623077, Validation score = 0.523077
# Epoch = 13, Loss = 1.08004, Training score = 0.634066, Validation score = 0.528205
# Epoch = 14, Loss = 1.05658, Training score = 0.640659, Validation score = 0.535897
# Epoch = 15, Loss = 1.03406, Training score = 0.649451, Validation score = 0.546154
# Epoch = 16, Loss = 1.013, Training score = 0.66044, Validation score = 0.553846
# Epoch = 17, Loss = 0.993423, Training score = 0.668132, Validation score = 0.558974
# Epoch = 18, Loss = 0.975245, Training score = 0.675824, Validation score = 0.55641
# Epoch = 19, Loss = 0.957509, Training score = 0.68022, Validation score = 0.558974
# Epoch = 20, Loss = 0.940818, Training score = 0.681319, Validation score = 0.55641
# Epoch = 21, Loss = 0.925175, Training score = 0.689011, Validation score = 0.55641
# Epoch = 22, Loss = 0.91032, Training score = 0.692308, Validation score = 0.569231
# Epoch = 23, Loss = 0.895331, Training score = 0.698901, Validation score = 0.571795
# Epoch = 24, Loss = 0.881897, Training score = 0.701099, Validation score = 0.571795
# Epoch = 25, Loss = 0.868627, Training score = 0.705495, Validation score = 0.574359
# Epoch = 26, Loss = 0.855513, Training score = 0.712088, Validation score = 0.574359
# Epoch = 27, Loss = 0.843049, Training score = 0.712088, Validation score = 0.587179
# Epoch = 28, Loss = 0.830766, Training score = 0.717582, Validation score = 0.594872
# Epoch = 29, Loss = 0.819218, Training score = 0.71978, Validation score = 0.594872
# Epoch = 30, Loss = 0.807624, Training score = 0.726374, Validation score = 0.594872
# Epoch = 31, Loss = 0.796623, Training score = 0.727473, Validation score = 0.594872
# Epoch = 32, Loss = 0.785777, Training score = 0.72967, Validation score = 0.592308
# Epoch = 33, Loss = 0.775337, Training score = 0.730769, Validation score = 0.589744
# Epoch = 34, Loss = 0.765109, Training score = 0.73956, Validation score = 0.589744
# Epoch = 35, Loss = 0.754547, Training score = 0.743956, Validation score = 0.597436
# Epoch = 36, Loss = 0.745033, Training score = 0.746154, Validation score = 0.607692
# Epoch = 37, Loss = 0.734867, Training score = 0.747253, Validation score = 0.620513
# Epoch = 38, Loss = 0.725294, Training score = 0.751648, Validation score = 0.620513
# Epoch = 39, Loss = 0.715828, Training score = 0.753846, Validation score = 0.623077
# Epoch = 40, Loss = 0.706509, Training score = 0.76044, Validation score = 0.617949
# Epoch = 41, Loss = 0.69733, Training score = 0.762637, Validation score = 0.630769
# Epoch = 42, Loss = 0.688479, Training score = 0.769231, Validation score = 0.638462
# Epoch = 43, Loss = 0.679376, Training score = 0.773626, Validation score = 0.648718
# Epoch = 44, Loss = 0.670656, Training score = 0.781319, Validation score = 0.648718
# Epoch = 45, Loss = 0.662166, Training score = 0.785714, Validation score = 0.648718
# Epoch = 46, Loss = 0.653618, Training score = 0.79011, Validation score = 0.65641
# Epoch = 47, Loss = 0.645266, Training score = 0.795604, Validation score = 0.653846
# Epoch = 48, Loss = 0.636576, Training score = 0.797802, Validation score = 0.661538
# Epoch = 49, Loss = 0.628527, Training score = 0.801099, Validation score = 0.651282
# Epoch = 50, Loss = 0.620145, Training score = 0.805495, Validation score = 0.658974
# Epoch = 51, Loss = 0.612241, Training score = 0.80989, Validation score = 0.666667
# Epoch = 52, Loss = 0.604293, Training score = 0.813187, Validation score = 0.669231
# Epoch = 53, Loss = 0.59634, Training score = 0.81978, Validation score = 0.671795
# Epoch = 54, Loss = 0.588895, Training score = 0.816484, Validation score = 0.671795
# Epoch = 55, Loss = 0.58131, Training score = 0.817582, Validation score = 0.674359
# Epoch = 56, Loss = 0.574069, Training score = 0.81978, Validation score = 0.682051
# Epoch = 57, Loss = 0.566654, Training score = 0.825275, Validation score = 0.684615
# Epoch = 58, Loss = 0.559538, Training score = 0.826374, Validation score = 0.687179
# Epoch = 59, Loss = 0.552334, Training score = 0.832967, Validation score = 0.689744
# Epoch = 60, Loss = 0.5456, Training score = 0.837363, Validation score = 0.694872
# Epoch = 61, Loss = 0.538593, Training score = 0.842857, Validation score = 0.692308
# Epoch = 62, Loss = 0.53155, Training score = 0.842857, Validation score = 0.694872
# Epoch = 63, Loss = 0.5248, Training score = 0.843956, Validation score = 0.697436
# Epoch = 64, Loss = 0.518209, Training score = 0.846154, Validation score = 0.697436
# Epoch = 65, Loss = 0.511749, Training score = 0.848352, Validation score = 0.694872
# Epoch = 66, Loss = 0.505111, Training score = 0.852747, Validation score = 0.692308
# Epoch = 67, Loss = 0.498581, Training score = 0.858242, Validation score = 0.692308
# Epoch = 68, Loss = 0.492576, Training score = 0.859341, Validation score = 0.697436
# Epoch = 69, Loss = 0.486414, Training score = 0.865934, Validation score = 0.694872
# Epoch = 70, Loss = 0.480177, Training score = 0.867033, Validation score = 0.697436
# Epoch = 71, Loss = 0.474262, Training score = 0.87033, Validation score = 0.697436
# Epoch = 72, Loss = 0.468091, Training score = 0.872527, Validation score = 0.7
# Epoch = 73, Loss = 0.461922, Training score = 0.875824, Validation score = 0.7
# Epoch = 74, Loss = 0.456261, Training score = 0.882418, Validation score = 0.7
# Epoch = 75, Loss = 0.450653, Training score = 0.884615, Validation score = 0.7
# Epoch = 76, Loss = 0.444973, Training score = 0.887912, Validation score = 0.697436
# Epoch = 77, Loss = 0.439402, Training score = 0.886813, Validation score = 0.7
# Epoch = 78, Loss = 0.433902, Training score = 0.886813, Validation score = 0.702564
# Epoch = 79, Loss = 0.42826, Training score = 0.889011, Validation score = 0.702564
# Epoch = 80, Loss = 0.423331, Training score = 0.889011, Validation score = 0.7
# Epoch = 81, Loss = 0.418268, Training score = 0.891209, Validation score = 0.7
# Epoch = 82, Loss = 0.41299, Training score = 0.893407, Validation score = 0.697436
# Epoch = 83, Loss = 0.407583, Training score = 0.897802, Validation score = 0.7
# Epoch = 84, Loss = 0.402792, Training score = 0.897802, Validation score = 0.702564
# Epoch = 85, Loss = 0.397854, Training score = 0.903297, Validation score = 0.705128
# Epoch = 86, Loss = 0.393299, Training score = 0.904396, Validation score = 0.705128
# Epoch = 87, Loss = 0.388395, Training score = 0.906593, Validation score = 0.707692
# Epoch = 88, Loss = 0.383854, Training score = 0.908791, Validation score = 0.705128
# Epoch = 89, Loss = 0.378938, Training score = 0.914286, Validation score = 0.707692
# Epoch = 90, Loss = 0.374345, Training score = 0.916484, Validation score = 0.710256
# Epoch = 91, Loss = 0.369874, Training score = 0.91978, Validation score = 0.710256
# Epoch = 92, Loss = 0.365279, Training score = 0.920879, Validation score = 0.712821
# Epoch = 93, Loss = 0.360661, Training score = 0.91978, Validation score = 0.710256
# Epoch = 94, Loss = 0.356238, Training score = 0.920879, Validation score = 0.707692
# Epoch = 95, Loss = 0.351874, Training score = 0.921978, Validation score = 0.705128
# Epoch = 96, Loss = 0.347766, Training score = 0.921978, Validation score = 0.705128
# Epoch = 97, Loss = 0.343701, Training score = 0.924176, Validation score = 0.705128
# Epoch = 98, Loss = 0.339622, Training score = 0.926374, Validation score = 0.707692
# Epoch = 99, Loss = 0.335218, Training score = 0.928571, Validation score = 0.705128
# Epoch = 100, Loss = 0.331379, Training score = 0.930769, Validation score = 0.705128
# Epoch = 101, Loss = 0.327438, Training score = 0.930769, Validation score = 0.707692
# Epoch = 102, Loss = 0.323333, Training score = 0.932967, Validation score = 0.705128
# Epoch = 103, Loss = 0.31954, Training score = 0.932967, Validation score = 0.705128
# Epoch = 104, Loss = 0.315728, Training score = 0.935165, Validation score = 0.702564
# Epoch = 105, Loss = 0.311822, Training score = 0.938462, Validation score = 0.702564
# Epoch = 106, Loss = 0.307956, Training score = 0.93956, Validation score = 0.7
# Epoch = 107, Loss = 0.304252, Training score = 0.938462, Validation score = 0.707692
# Epoch = 108, Loss = 0.300419, Training score = 0.93956, Validation score = 0.710256
# Epoch = 109, Loss = 0.296947, Training score = 0.941758, Validation score = 0.712821
# Epoch = 110, Loss = 0.293252, Training score = 0.942857, Validation score = 0.710256
# Epoch = 111, Loss = 0.289726, Training score = 0.943956, Validation score = 0.707692
# Epoch = 112, Loss = 0.286343, Training score = 0.946154, Validation score = 0.707692
# Epoch = 113, Loss = 0.282652, Training score = 0.949451, Validation score = 0.712821
# Epoch = 114, Loss = 0.279074, Training score = 0.950549, Validation score = 0.710256
# Epoch = 115, Loss = 0.275728, Training score = 0.952747, Validation score = 0.712821
# Epoch = 116, Loss = 0.272206, Training score = 0.952747, Validation score = 0.712821
# Epoch = 117, Loss = 0.268955, Training score = 0.953846, Validation score = 0.715385
# Epoch = 118, Loss = 0.265496, Training score = 0.956044, Validation score = 0.710256
# Epoch = 119, Loss = 0.262176, Training score = 0.957143, Validation score = 0.710256
# Epoch = 120, Loss = 0.259108, Training score = 0.954945, Validation score = 0.710256
# Epoch = 121, Loss = 0.255865, Training score = 0.956044, Validation score = 0.707692
# Epoch = 122, Loss = 0.252726, Training score = 0.958242, Validation score = 0.705128
# Epoch = 123, Loss = 0.249442, Training score = 0.959341, Validation score = 0.702564
# Epoch = 124, Loss = 0.246511, Training score = 0.959341, Validation score = 0.7
# Epoch = 125, Loss = 0.243398, Training score = 0.959341, Validation score = 0.705128
# Epoch = 126, Loss = 0.240673, Training score = 0.961538, Validation score = 0.702564
# Epoch = 127, Loss = 0.237478, Training score = 0.962637, Validation score = 0.702564
# Epoch = 128, Loss = 0.234635, Training score = 0.963736, Validation score = 0.702564
# Epoch = 129, Loss = 0.231573, Training score = 0.965934, Validation score = 0.702564
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=130, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=True)

# %%
mlperc(max_iter = 130,normalize=False, n_components=0.9)
# Out:
# not normalized
# nc=17
# Epoch = 0, Loss = 1.98726, Training score = 0.293407, Validation score = 0.261538
# Epoch = 1, Loss = 1.74413, Training score = 0.342857, Validation score = 0.330769
# Epoch = 2, Loss = 1.56928, Training score = 0.386813, Validation score = 0.361538
# Epoch = 3, Loss = 1.43298, Training score = 0.432967, Validation score = 0.428205
# Epoch = 4, Loss = 1.32772, Training score = 0.501099, Validation score = 0.474359
# Epoch = 5, Loss = 1.2439, Training score = 0.532967, Validation score = 0.507692
# Epoch = 6, Loss = 1.1759, Training score = 0.569231, Validation score = 0.528205
# Epoch = 7, Loss = 1.1176, Training score = 0.598901, Validation score = 0.535897
# Epoch = 8, Loss = 1.06765, Training score = 0.625275, Validation score = 0.569231
# Epoch = 9, Loss = 1.02609, Training score = 0.647253, Validation score = 0.579487
# Epoch = 10, Loss = 0.989202, Training score = 0.659341, Validation score = 0.592308
# C:\Users\a_mon\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Epoch = 11, Loss = 0.957137, Training score = 0.671429, Validation score = 0.602564
# Epoch = 12, Loss = 0.928179, Training score = 0.683516, Validation score = 0.612821
# Epoch = 13, Loss = 0.901842, Training score = 0.693407, Validation score = 0.620513
# Epoch = 14, Loss = 0.879609, Training score = 0.706593, Validation score = 0.641026
# Epoch = 15, Loss = 0.857634, Training score = 0.717582, Validation score = 0.651282
# Epoch = 16, Loss = 0.837889, Training score = 0.721978, Validation score = 0.651282
# Epoch = 17, Loss = 0.819622, Training score = 0.735165, Validation score = 0.65641
# Epoch = 18, Loss = 0.802557, Training score = 0.73956, Validation score = 0.664103
# Epoch = 19, Loss = 0.785918, Training score = 0.745055, Validation score = 0.661538
# Epoch = 20, Loss = 0.770346, Training score = 0.749451, Validation score = 0.666667
# Epoch = 21, Loss = 0.755608, Training score = 0.762637, Validation score = 0.671795
# Epoch = 22, Loss = 0.742099, Training score = 0.77033, Validation score = 0.671795
# Epoch = 23, Loss = 0.728265, Training score = 0.771429, Validation score = 0.679487
# Epoch = 24, Loss = 0.715518, Training score = 0.773626, Validation score = 0.682051
# Epoch = 25, Loss = 0.703294, Training score = 0.775824, Validation score = 0.689744
# Epoch = 26, Loss = 0.691393, Training score = 0.782418, Validation score = 0.694872
# Epoch = 27, Loss = 0.679672, Training score = 0.787912, Validation score = 0.697436
# Epoch = 28, Loss = 0.668301, Training score = 0.792308, Validation score = 0.710256
# Epoch = 29, Loss = 0.65759, Training score = 0.795604, Validation score = 0.712821
# Epoch = 30, Loss = 0.647028, Training score = 0.8, Validation score = 0.717949
# Epoch = 31, Loss = 0.636612, Training score = 0.801099, Validation score = 0.723077
# Epoch = 32, Loss = 0.626833, Training score = 0.803297, Validation score = 0.728205
# Epoch = 33, Loss = 0.616931, Training score = 0.808791, Validation score = 0.730769
# Epoch = 34, Loss = 0.607644, Training score = 0.812088, Validation score = 0.730769
# Epoch = 35, Loss = 0.59834, Training score = 0.816484, Validation score = 0.728205
# Epoch = 36, Loss = 0.589553, Training score = 0.817582, Validation score = 0.730769
# Epoch = 37, Loss = 0.580329, Training score = 0.81978, Validation score = 0.730769
# Epoch = 38, Loss = 0.571827, Training score = 0.825275, Validation score = 0.730769
# Epoch = 39, Loss = 0.563604, Training score = 0.826374, Validation score = 0.725641
# Epoch = 40, Loss = 0.555497, Training score = 0.828571, Validation score = 0.728205
# Epoch = 41, Loss = 0.547286, Training score = 0.834066, Validation score = 0.728205
# Epoch = 42, Loss = 0.539363, Training score = 0.83956, Validation score = 0.733333
# Epoch = 43, Loss = 0.531517, Training score = 0.840659, Validation score = 0.741026
# Epoch = 44, Loss = 0.523857, Training score = 0.843956, Validation score = 0.741026
# Epoch = 45, Loss = 0.516576, Training score = 0.845055, Validation score = 0.738462
# Epoch = 46, Loss = 0.508836, Training score = 0.851648, Validation score = 0.751282
# Epoch = 47, Loss = 0.501918, Training score = 0.851648, Validation score = 0.74359
# Epoch = 48, Loss = 0.494503, Training score = 0.857143, Validation score = 0.74359
# Epoch = 49, Loss = 0.487705, Training score = 0.858242, Validation score = 0.748718
# Epoch = 50, Loss = 0.480537, Training score = 0.859341, Validation score = 0.748718
# Epoch = 51, Loss = 0.474097, Training score = 0.864835, Validation score = 0.746154
# Epoch = 52, Loss = 0.467265, Training score = 0.869231, Validation score = 0.751282
# Epoch = 53, Loss = 0.460449, Training score = 0.87033, Validation score = 0.751282
# Epoch = 54, Loss = 0.454457, Training score = 0.879121, Validation score = 0.751282
# Epoch = 55, Loss = 0.448007, Training score = 0.88022, Validation score = 0.753846
# Epoch = 56, Loss = 0.44206, Training score = 0.881319, Validation score = 0.748718
# Epoch = 57, Loss = 0.436214, Training score = 0.883516, Validation score = 0.748718
# Epoch = 58, Loss = 0.430088, Training score = 0.882418, Validation score = 0.751282
# Epoch = 59, Loss = 0.424209, Training score = 0.885714, Validation score = 0.751282
# Epoch = 60, Loss = 0.418705, Training score = 0.886813, Validation score = 0.748718
# Epoch = 61, Loss = 0.412763, Training score = 0.892308, Validation score = 0.753846
# Epoch = 62, Loss = 0.406904, Training score = 0.892308, Validation score = 0.751282
# Epoch = 63, Loss = 0.401716, Training score = 0.898901, Validation score = 0.748718
# Epoch = 64, Loss = 0.39622, Training score = 0.897802, Validation score = 0.751282
# Epoch = 65, Loss = 0.391135, Training score = 0.9, Validation score = 0.758974
# Epoch = 66, Loss = 0.385516, Training score = 0.902198, Validation score = 0.758974
# Epoch = 67, Loss = 0.380247, Training score = 0.903297, Validation score = 0.761538
# Epoch = 68, Loss = 0.375457, Training score = 0.906593, Validation score = 0.758974
# Epoch = 69, Loss = 0.370424, Training score = 0.90989, Validation score = 0.748718
# Epoch = 70, Loss = 0.365308, Training score = 0.912088, Validation score = 0.748718
# Epoch = 71, Loss = 0.360371, Training score = 0.912088, Validation score = 0.753846
# Epoch = 72, Loss = 0.355359, Training score = 0.914286, Validation score = 0.751282
# Epoch = 73, Loss = 0.350252, Training score = 0.917582, Validation score = 0.751282
# Epoch = 74, Loss = 0.345722, Training score = 0.918681, Validation score = 0.751282
# Epoch = 75, Loss = 0.340943, Training score = 0.920879, Validation score = 0.753846
# Epoch = 76, Loss = 0.336411, Training score = 0.920879, Validation score = 0.753846
# Epoch = 77, Loss = 0.331819, Training score = 0.923077, Validation score = 0.753846
# Epoch = 78, Loss = 0.327466, Training score = 0.927473, Validation score = 0.751282
# Epoch = 79, Loss = 0.322935, Training score = 0.928571, Validation score = 0.753846
# Epoch = 80, Loss = 0.318942, Training score = 0.928571, Validation score = 0.753846
# Epoch = 81, Loss = 0.314749, Training score = 0.92967, Validation score = 0.753846
# Epoch = 82, Loss = 0.310277, Training score = 0.931868, Validation score = 0.75641
# Epoch = 83, Loss = 0.305952, Training score = 0.935165, Validation score = 0.75641
# Epoch = 84, Loss = 0.302156, Training score = 0.935165, Validation score = 0.75641
# Epoch = 85, Loss = 0.298156, Training score = 0.934066, Validation score = 0.75641
# Epoch = 86, Loss = 0.294296, Training score = 0.937363, Validation score = 0.753846
# Epoch = 87, Loss = 0.290462, Training score = 0.937363, Validation score = 0.75641
# Epoch = 88, Loss = 0.286757, Training score = 0.940659, Validation score = 0.764103
# Epoch = 89, Loss = 0.282724, Training score = 0.942857, Validation score = 0.761538
# Epoch = 90, Loss = 0.278854, Training score = 0.942857, Validation score = 0.764103
# Epoch = 91, Loss = 0.275311, Training score = 0.943956, Validation score = 0.761538
# Epoch = 92, Loss = 0.271632, Training score = 0.942857, Validation score = 0.761538
# Epoch = 93, Loss = 0.267756, Training score = 0.945055, Validation score = 0.764103
# Epoch = 94, Loss = 0.26413, Training score = 0.943956, Validation score = 0.766667
# Epoch = 95, Loss = 0.260511, Training score = 0.948352, Validation score = 0.764103
# Epoch = 96, Loss = 0.257262, Training score = 0.948352, Validation score = 0.764103
# Epoch = 97, Loss = 0.253851, Training score = 0.950549, Validation score = 0.769231
# Epoch = 98, Loss = 0.250518, Training score = 0.949451, Validation score = 0.769231
# Epoch = 99, Loss = 0.246901, Training score = 0.956044, Validation score = 0.764103
# Epoch = 100, Loss = 0.244089, Training score = 0.956044, Validation score = 0.766667
# Epoch = 101, Loss = 0.240723, Training score = 0.953846, Validation score = 0.769231
# Epoch = 102, Loss = 0.237517, Training score = 0.953846, Validation score = 0.766667
# Epoch = 103, Loss = 0.234335, Training score = 0.954945, Validation score = 0.764103
# Epoch = 104, Loss = 0.231203, Training score = 0.956044, Validation score = 0.761538
# Epoch = 105, Loss = 0.228181, Training score = 0.96044, Validation score = 0.764103
# Epoch = 106, Loss = 0.225159, Training score = 0.961538, Validation score = 0.761538
# Epoch = 107, Loss = 0.222058, Training score = 0.962637, Validation score = 0.758974
# Epoch = 108, Loss = 0.218966, Training score = 0.963736, Validation score = 0.761538
# Epoch = 109, Loss = 0.216137, Training score = 0.964835, Validation score = 0.761538
# Epoch = 110, Loss = 0.213349, Training score = 0.964835, Validation score = 0.764103
# Epoch = 111, Loss = 0.210416, Training score = 0.967033, Validation score = 0.761538
# Epoch = 112, Loss = 0.207913, Training score = 0.965934, Validation score = 0.761538
# Epoch = 113, Loss = 0.205186, Training score = 0.967033, Validation score = 0.758974
# Epoch = 114, Loss = 0.202276, Training score = 0.971429, Validation score = 0.75641
# Epoch = 115, Loss = 0.199735, Training score = 0.972527, Validation score = 0.769231
# Epoch = 116, Loss = 0.196911, Training score = 0.972527, Validation score = 0.764103
# Epoch = 117, Loss = 0.194503, Training score = 0.97033, Validation score = 0.766667
# Epoch = 118, Loss = 0.191615, Training score = 0.972527, Validation score = 0.769231
# Epoch = 119, Loss = 0.18899, Training score = 0.974725, Validation score = 0.769231
# Epoch = 120, Loss = 0.186679, Training score = 0.978022, Validation score = 0.766667
# Epoch = 121, Loss = 0.183999, Training score = 0.976923, Validation score = 0.766667
# Epoch = 122, Loss = 0.181748, Training score = 0.979121, Validation score = 0.761538
# Epoch = 123, Loss = 0.179063, Training score = 0.98022, Validation score = 0.758974
# Epoch = 124, Loss = 0.176686, Training score = 0.98022, Validation score = 0.758974
# Epoch = 125, Loss = 0.174285, Training score = 0.98022, Validation score = 0.75641
# Epoch = 126, Loss = 0.172291, Training score = 0.981319, Validation score = 0.751282
# Epoch = 127, Loss = 0.169664, Training score = 0.981319, Validation score = 0.758974
# Epoch = 128, Loss = 0.167464, Training score = 0.982418, Validation score = 0.75641
# Epoch = 129, Loss = 0.165034, Training score = 0.982418, Validation score = 0.75641
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=130, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=True)

# %% [markdown]
# Why is label 3 always the one with more wrong predictions?

# %% [markdown]
# I try to choose the best parameters all togheter to be quick, I use sklearn.model_selection.RandomizedSearchCV

# %%
import random 
def change_all(num_train = 910, num_test = 390, normalize = False,n_components = 0.9,**mlp_params):
    data = parse_data(num_train, num_test,normalize,n_components)
    # prepare a uniform distribution to sample for the alpha parameter
    param_distributions = {'alpha' : [random.uniform(1e-6, 1e-1) for k in range(10)],
                           'batch_size' : [random.randint(10, 200) for k in range(10)],
                           'learning_rate_init' : [random.uniform(1e-6, 1e-1) for k in range(10)],
                           'hidden_layer_sizes' : [ ( random.randint(1, 200), random.randint(1, 100) ) for k in range(10)], #What is the architecture? what happens if we add more layers?
                           'activation' : ['identity', 'logistic', 'tanh', 'relu'],   #What is the activation function between neurons?
                           'learning_rate' : ['constant', 'invscaling', 'adaptive'], #How does the learning rate update itself?
                           'solver' : ['lbfgs', 'sgd', 'adam'],
                          }
    
    # create and fit a mlp model, testing random alpha values
    model = MLPClassifier(**mlp_params)
    n_search_iter = 5
    rs = RandomizedSearchCV(estimator = model, n_iter = n_search_iter, param_distributions = param_distributions, cv =5)
    rs.fit(*data.train())

    # evaluate the best randomized searched model on the testing data
    print('Best score: {}'.format(rs.best_score_))
    print('Best parameters: {}'.format(rs.best_params_))
    return model

# %%
rs = change_all()
# Out:
# normalized
# nc=17
# C:\Users\a_mon\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Best score: 0.7065934065934066
# Best parameters: {'solver': 'lbfgs', 'learning_rate_init': 0.08751794979100458, 'learning_rate': 'adaptive', 'hidden_layer_sizes': (112, 81), 'batch_size': 191, 'alpha': 0.008609744888626673, 'activation': 'relu'}

# %%
mlp_cv = mlperc(max_iter = 30,
           normalize=False, 
           n_components=0.9,
           activation = 'tanh',
           hidden_layer_sizes = (186, 84),
           learning_rate = 'adaptive', 
           batch_size = 89,
           alpha = 0.0441705505832946,
           learning_rate_init = 0.084460914188957,
           solver= 'sgd')
# Out:
# not normalized
# nc=17
# Epoch = 0, Loss = 1.32826, Training score = 0.612088, Validation score = 0.579487
# Epoch = 1, Loss = 1.01834, Training score = 0.672527, Validation score = 0.592308
# C:\Users\a_mon\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Epoch = 2, Loss = 0.866039, Training score = 0.752747, Validation score = 0.641026
# Epoch = 3, Loss = 0.733916, Training score = 0.757143, Validation score = 0.661538
# Epoch = 4, Loss = 0.649646, Training score = 0.837363, Validation score = 0.676923
# Epoch = 5, Loss = 0.516019, Training score = 0.868132, Validation score = 0.671795
# Epoch = 6, Loss = 0.43796, Training score = 0.930769, Validation score = 0.741026
# Epoch = 7, Loss = 0.332207, Training score = 0.925275, Validation score = 0.692308
# Epoch = 8, Loss = 0.273503, Training score = 0.974725, Validation score = 0.774359
# Epoch = 9, Loss = 0.209455, Training score = 0.951648, Validation score = 0.720513
# Epoch = 10, Loss = 0.19592, Training score = 0.974725, Validation score = 0.723077
# Epoch = 11, Loss = 0.163899, Training score = 0.997802, Validation score = 0.753846
# Epoch = 12, Loss = 0.132064, Training score = 1, Validation score = 0.769231
# Epoch = 13, Loss = 0.115453, Training score = 1, Validation score = 0.758974
# Epoch = 14, Loss = 0.106189, Training score = 1, Validation score = 0.75641
# Epoch = 15, Loss = 0.10106, Training score = 1, Validation score = 0.771795
# Epoch = 16, Loss = 0.0976876, Training score = 1, Validation score = 0.771795
# Epoch = 17, Loss = 0.0955497, Training score = 1, Validation score = 0.774359
# Epoch = 18, Loss = 0.0933146, Training score = 1, Validation score = 0.766667
# Epoch = 19, Loss = 0.0922181, Training score = 1, Validation score = 0.779487
# Epoch = 20, Loss = 0.0911063, Training score = 1, Validation score = 0.774359
# Epoch = 21, Loss = 0.0898262, Training score = 1, Validation score = 0.771795
# Epoch = 22, Loss = 0.0886226, Training score = 1, Validation score = 0.776923
# Epoch = 23, Loss = 0.0877371, Training score = 1, Validation score = 0.776923
# Epoch = 24, Loss = 0.0868855, Training score = 1, Validation score = 0.771795
# Epoch = 25, Loss = 0.0860403, Training score = 1, Validation score = 0.774359
# Epoch = 26, Loss = 0.0853845, Training score = 1, Validation score = 0.776923
# Epoch = 27, Loss = 0.0848456, Training score = 1, Validation score = 0.779487
# Epoch = 28, Loss = 0.0840856, Training score = 1, Validation score = 0.771795
# Epoch = 29, Loss = 0.083543, Training score = 1, Validation score = 0.774359

# %%
mlp_cv_= MLPClassifier(activation = 'tanh',
                       hidden_layer_sizes = (186, 84),
                       learning_rate = 'adaptive', 
                       batch_size = 89,
                       alpha = 0.0441705505832946,
                       learning_rate_init = 0.084460914188957,
                       solver= 'sgd')

# %% [markdown]
# It seems to overfit, as we can see it achieves training score=1 after few epochs

# %% [markdown]
# Perform k fold and save the score

# %%
mlp_cvscore = kfold(model = mlp_cv_,n_splits=8,features=features_1,target=target)
# Out:
# C:\Users\a_mon\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Training score = 1, Validation score = 0.828221
# Training score = 1, Validation score = 0.779141
# Training score = 1, Validation score = 0.797546
# Training score = 1, Validation score = 0.809816
# Training score = 1, Validation score = 0.814815
# Training score = 1, Validation score = 0.820988
# Training score = 1, Validation score = 0.802469
# Training score = 1, Validation score = 0.820988
# CV accuracy = 0.809248

# %%
d['MLP'] = mlp_cvscore

# %% [markdown]
# # Conclusions

# %% [markdown]
# I previously created a dictionary so I could save all the cross validation scores of the models I have been using:

# %%
d
# Out:
# {'Knn': 0.7531432250246155,
#  'MLP': 0.80924789820495346,
#  'Random Forest': 0.71081383019010835}

# %% [markdown]
# The MLP performs very good, but also KNN works fine and so does Random Forest. There was no need for normalization, data were already normally distributed and PCA didn't do much because of the structure of the data.
