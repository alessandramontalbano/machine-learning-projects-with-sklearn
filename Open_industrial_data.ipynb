# %% [markdown]
# # Big data for industrial operations

# %% [markdown]
# #### What is the topic?
# **"Industry 4.0"**, which consists in that data created by industrial equipment might hold more potential business values. It uses raw data to support management decision making, so to reduce costs in maintenance and improve customer service.
#
# In particular:
#
# For the **oil and gas industry** to succeed in the current reality they need to take full advantage of digital transformation opportunities, in this way they will be able to take better decision, reduce risk and ensure efficient use of resources.
# Big data is available from virtually every aspect of drilling, production, operations and mainteinance.
# Businesses need to keep pace with their ability to process and analyze that data, to ensure that machines are working properly and check whether a machine is going to breakdown or fail and to improve production performance.
#
#
# -----------------------------------------------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------------------------------------------
#
# I am going to analyse data from https://openindustrialdata.com/
#
# The data originates from a single **compressor on Aker BP’s Valhall oil platform in the North Sea.**
#
#
#
# It includes *time series data*, *maintenance history data*, and *Process & Instrumentation Diagrams (P&IDs)* for Valhall’s first **stage compressor and associated process equipment**: first stage suction cooler, first stage suction scrubber, first stage compressor and first stage discharge coolers. In addition, data from the compressor’s lubrication system, dry gas seal system and condition monitoring system (temperature and vibration) will be available.
#
# (The idea is to use Time Series Data to see how factors change over time)
#
# #### Some of the questions that might be interesting to answer (not all):
#
# - **When gathering data from oil platforms, specific sensors can be very expensive to install and maintain, can you find combination of other sensor readings to predict another?**
#  (Linear regression, MLP, RandomForest...)
#
#
# - **What is the typical difference between the input and output pressure of the compressor?**
#  (Correlation between input and output over time, AR model?)
#
#
# - **Can you infer the thermal efficiency of the 1st stage suction cooler from sensor data?**
#  (?)
#
#
# - **How do the above compare to the specifications in the process diagram?**
#  (?)
#
#
# - **What is the typical start-up time of the compressor, from standstill to stable operation?**
#  (?)

# %% [markdown]
# I'm going to use data from the Cognitive Data Platform, using the API.
# Here is the documentation: https://cognite-sdk-python.readthedocs-hosted.com/en/latest/index.html

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

import os
from datetime import datetime, timedelta
from datetime import datetime
from getpass import getpass


from cognite import CogniteClient

# %%
client = CogniteClient(api_key=getpass("API-KEY: "))
# Out:
# API-KEY: ········

# %% [markdown]
# #### What is an asset?
#
# Assets are digital representations of physical objects or groups of objects, and assets are organized into an asset hierarchy. For example, an asset can represent a water pump which is part of a subsystem on an oil platform. They are used to connect related data together.

# %% [markdown]
# Get the dataset (as we can observe, we have first and second stage compressors, valves, others...):

# %%
asset_df=client.assets.get_assets().to_pandas()
asset_df
# Out:
#      createdTime  depth                                        description  \
# 0              0      2              GAS COMPRESSION AND RE-INJECTION (PH)
# 1              0      7              1ST STAGE COMP DRY GAS SEAL SYS ON PH
# 2              0      7                     1ST STAGE COMP ENCLOSURE ON PH
# 3              0      7                  1ST STAGE COMP LUBE OIL SYS ON PH
# 4              0      4                        1ST STAGE COMPRESSION ON PH
# 5              0      5                         1ST STAGE COMPRESSOR ON PH
# 6              0      7              2ND STAGE COMP DRY GAS SEAL SYS ON PH
# 7              0      4                        2ND STAGE COMPRESSION ON PH
# 8              0      5                         2ND STAGE COMPRESSOR ON PH
# 9              0      6                    VRD - PH 1STSTGSUCT SCRUB INLET
# 10             0      6                  VRD - PH 1STSTGSUCT SCRUB GAS OUT
# 11             0      6                  VRD - PH 1STSTGSUCT SCRUB LIQ OUT
# 12             0      8       VRD - 1ST STAGE COMPRESSOR LUBE OIL FILTER A
# 13             0      8       VRD - 1ST STAGE COMPRESSOR LUBE OIL FILTER B
# 14             0      8       VRD - 1ST STAGE COMPRESSOR GAS SEAL FILTER A
# 15             0      8       VRD - 1ST STAGE COMPRESSOR GAS SEAL FILTER B
# 16             0      8       VRD - 1ST STAGE COMPRESSOR NITROGEN FILTER A
# 17             0      8       VRD - 1ST STAGE COMPRESSOR NITROGEN FILTER B
# 18             0      9  VRD - 1ST STAGE COMPRESSOR SEAL GAS BOOSTER FI...
# 19             0      8  VRD - DRIVE-AIR FILTER SEAL GAS  STAGE 1 COMPR...
# 20             0      6              VRD - 1ST STAGE COMPRESSOR PURGE UNIT
# 21             0      8               VRD - 1ST STAGE COMPRESSOR GEAR UNIT
# 22             0      8  VRD - 1ST STAGE COMPPRESSOR ENCLOSURE COALESCE...
# 23             0      8                      VRD - PH 1STSTGSUCTCLR GAS IN
# 24             0      8                VRD - PH 1STSTGSUCTCLR GAS IN EQUAL
# 25             0      7                VRD - PH 1ST STG SUCT SCRUB LIQ OUT
# 26             0      8                  VRD - PH 1ST STG SUCT CLR GAS OUT
# 27             0      8            VRD - PH 1ST STG SUCT CLR GAS OUT EQUAL
# 28             0      8                      VRD - PH 1STSTGSUCTCLR GAS IN
# 29             0      8                VRD - PH 1STSTGSUCTCLR GAS IN EQUAL
# ..           ...    ...                                                ...
# 970            0      8                  VRD - PH 1STSTG COMPR ENCL DOOR A
# 971            0      8                  VRD - PH 1STSTG COMPR ENCL DOOR B
# 972            0      8                  VRD - PH 1STSTG COMPR ENCL DOOR C
# 973            0      8                    VRD - PH 1STSTGCOMP SUCTION STV
# 974            0      9           SOFT TAG VRD - PH 1STSTGCOMP SUCTION STV
# 975            0      8                     VRD - PH 1STSTGCOMP ANTI-SURGE
# 976            0      9        SOFT TAG VRD - PH 1STSTGCOMP VALVE POSITION
# 977            0      9                VRD - PH 1STSTGCOMP SHAFT AXIAL POS
# 978            0      9                VRD - PH 1STSTGCOMP SHAFT AXIAL POS
# 979            0      9                VRD - PH 1STSTGCOMP SHAFT AXIAL POS
# 980            0     10                VRD - PH 1STSTGGEAR SHAFT AXIAL POS
# 981            0     10                VRD - PH 1STSTGGEAR SHAFT AXIAL POS
# 982            0     10                VRD - PH 1STSTGGEAR SHAFT AXIAL POS
# 983            0      3             GAS COMPRESSION AND RE-INJECTION ON PH
# 984            0      8  VRD - PH 1STSTGSUCTCOOL COOLMED IN : FLOW ALAR...
# 985            0      9  VRD - PH 1STSTGDISCCOOL COOLMED IN : FLOW ALAR...
# 986            0     10  VRD - PH 1STSTGCOMPR MTR COOLMED OUT : FLOW AL...
'ELC_STATUS_ID': '1211', 'SOURCE_DB': 'workma...
# 9    {'ELC_STATUS_ID': '1211', 'RES_ID': '531669', ...
# 10   {'ELC_STATUS_ID': '1211', 'RES_ID': '531669', ...
# 11   {'ELC_STATUS_ID': '1211', 'RES_ID': '531668', ...
# 12   {'ELC_STATUS_ID': '1211', 'RES_ID': '746776', ...
# 13   {'ELC_STATUS_ID': '1211', 'RES_ID': '746776', ...
# 14   {'ELC_STATUS_ID': '1211', 'SOURCE_DB': 'workma...
# 15   {'ELC_STATUS_ID': '1211', 'SOURCE_DB': 'workma...
# 16   {'ELC_STATUS_ID': '1211', 'SOURCE_DB': 'workma...
# 17   {'ELC_STATUS_ID': '1211', 'SOURCE_DB': 'workma...
# 18   {'ELC_STATUS_ID': '1211', 'SOURCE_DB': 'workma...
# 19   {'ELC_STATUS_ID': '1211', 'SOURCE_DB': 'workma...
# 20   {'ELC_STATUS_ID': '1211', 'SOURCE_DB': 'workma...
# 21   {'ELC_STATUS_ID': '1211', 'RES_ID': '490395', ...
# 22   {'ELC_STATUS_ID': '1211', 'SOURCE_DB': 'workma...
# 23   {'ELC_STATUS_ID': '1211', 'RES_ID': '532127', ...
# 24   {'ELC_STATUS_ID': '1211', 'RES_ID': '532127', ...
# 25   {'ELC_STATUS_ID': '1211', 'RES_ID': '532127', ...
# 26   {'ELC_STATUS_ID': '1211', 'RES_ID': '532127', ...
# 27   {'ELC_STATUS_ID': '1211', 'RES_ID': '532127', ...
# 28   {'ELC_STATUS_ID': '1211', 'RES_ID': '530799', ...
# 29   {'ELC_STATUS_ID': '1211', 'RES_ID': '530799', ...
# ..                                                 ...
# 970  {'ELC_STATUS_ID': '1211', 'RES_ID': '407894', ...
# 971  {'ELC_STATUS_ID': '1211', 'RES_ID': '407894', ...
# 972  {'ELC_STATUS_ID': '1225', 'SOURCE_DB': 'workma...
# 973  {'ELC_STATUS_ID': '1211', 'SOURCE_DB': 'workma...
# 974  {'ELC_STATUS_ID': '1211', 'SOURCE_DB': 'workma...
# 975  {'ELC_STATUS_ID': '1211', 'SOURCE_DB': 'workma...
# 976  {'ELC_STATUS_ID': '1211', 'SOURCE_DB': 'workma...
# 977  {'ELC_STATUS_ID': '1211', 'RES_ID': '446683', ...
# 978  {'ELC_STATUS_ID': '1211', 'RES_ID': '446683', ...
# 979  {'ELC_STATUS_ID': '1211', 'RES_ID': '446683', ...
# 980  {'ELC_STATUS_ID': '1211', 'RES_ID': '300992', ...
# 981  {'ELC_STATUS_ID': '1211', 'RES_ID': '300992', ...
# 982  {'ELC_STATUS_ID': '1211', 'RES_ID': '300992', ...
# 983  {'ELC_STATUS_ID': '1211', 'SOURCE_DB': 'workma...
# 984  {'ELC_STATUS_ID': '1211', 'SOURCE_DB': 'workma...
# 985  {'ELC_STATUS_ID': '1211', 'SOURCE_DB': 'workma...
# 986  {'ELC_STATUS_ID': '1211', 'SOURCE_DB': 'workma...
# 987  {'ELC_STATUS_ID': '1211', 'SOURCE_DB': 'workma...
# 988  {'ELC_STATUS_ID': '1211', 'RES_ID': '530545', ...
# 989  {'ELC_STATUS_ID': '1211', 'RES_ID': '530514', ...
# 990  {'ELC_STATUS_ID': '1211', 'SOURCE_DB': 'workma...
# 991  {'ELC_STATUS_ID': '1211', 'SOURCE_DB': 'workma...
# 992  {'ELC_STATUS_ID': '1211', 'SOURCE_DB': 'workma...
# 993  {'ELC_STATUS_ID': '1211', 'SOURCE_DB': 'workma...
# 994  {'ELC_STATUS_ID': '1211', 'SOURCE_DB': 'workma...
# 995  {'ELC_STATUS_ID': '1211', 'SOURCE_DB': 'workma...
# 996  {'ELC_STATUS_ID': '1211', 'RES_ID': '523857', ...
# 997  {'ELC_STATUS_ID': '1211', 'RES_ID': '523857', ...
# 998  {'ELC_STATUS_ID': '1211', 'RES_ID': '503584', ...
# 999  {'ELC_STATUS_ID': '1211', 'RES_ID': '503584', ...
#
#                                       name          parentId  \
# 0                                       23  4650652196144007
# 1    23-1ST STAGE COMP DRY GAS SEAL SYS-PH  4856008121737468
# 2           23-1ST STAGE COMP ENCLOSURE-PH  4856008121737468
# 3        23-1ST STAGE COMP LUBE OIL SYS-PH  4856008121737468
# 4              23-1ST STAGE COMPRESSION-PH  6895991969886325
# 5               23-1ST STAGE COMPRESSOR-PH  4518112062673878
# 6    23-2ND STAGE COMP DRY GAS SEAL SYS-PH  4222791488928479
# 7              23-2ND STAGE COMPRESSION-PH  6895991969886325
# 8               23-2ND STAGE COMPRESSOR-PH  5786472304680477
# 9                           23-AE-92527-S1    53231887945301
# 15   [6687602007296940, 4650652196144007, 311145472...
# 16   [6687602007296940, 4650652196144007, 311145472...
# 17   [6687602007296940, 4650652196144007, 311145472...
# 18   [6687602007296940, 4650652196144007, 311145472...
# 19   [6687602007296940, 4650652196144007, 311145472...
# 20   [6687602007296940, 4650652196144007, 311145472...
# 21   [6687602007296940, 4650652196144007, 311145472...
# 22   [6687602007296940, 4650652196144007, 311145472...
# 23   [6687602007296940, 4650652196144007, 311145472...
# 24   [6687602007296940, 4650652196144007, 311145472...
# 25   [6687602007296940, 4650652196144007, 311145472...
# 26   [6687602007296940, 4650652196144007, 311145472...
# 27   [6687602007296940, 4650652196144007, 311145472...
# 28   [6687602007296940, 4650652196144007, 311145472...
# 29   [6687602007296940, 4650652196144007, 311145472...
# ..                                                 ...
# 970  [6687602007296940, 4650652196144007, 311145472...
# 971  [6687602007296940, 4650652196144007, 311145472...
# 972  [6687602007296940, 4650652196144007, 311145472...
# 973  [6687602007296940, 4650652196144007, 311145472...
# 974  [6687602007296940, 4650652196144007, 311145472...
# 975  [6687602007296940, 4650652196144007, 311145472...
# 976  [6687602007296940, 4650652196144007, 311145472...
# 977  [6687602007296940, 4650652196144007, 311145472...
# 978  [6687602007296940, 4650652196144007, 311145472...
# 979  [6687602007296940, 4650652196144007, 311145472...
# 980  [6687602007296940, 4650652196144007, 311145472...
# 981  [6687602007296940, 4650652196144007, 311145472...
# 982  [6687602007296940, 4650652196144007, 311145472...
# 983  [6687602007296940, 4650652196144007, 311145472...
# 984  [6687602007296940, 4650652196144007, 311145472...
# 985  [6687602007296940, 4650652196144007, 311145472...
# 986  [6687602007296940, 4650652196144007, 311145472...
# 987  [6687602007296940, 4650652196144007, 311145472...
# 988  [6687602007296940, 4650652196144007, 311145472...
# 989  [6687602007296940, 4650652196144007, 311145472...
# 990  [6687602007296940, 4650652196144007, 311145472...
# 991  [6687602007296940, 4650652196144007, 311145472...
# 992  [6687602007296940, 4650652196144007, 311145472...
# 993  [6687602007296940, 4650652196144007, 311145472...
# 994  [6687602007296940, 4650652196144007, 311145472...
# 995  [6687602007296940, 4650652196144007, 311145472...
# 996  [6687602007296940, 4650652196144007, 311145472...
# 997  [6687602007296940, 4650652196144007, 311145472...
# 998  [6687602007296940, 4650652196144007, 311145472...
# 999  [6687602007296940, 4650652196144007, 311145472...
#
# [1000 rows x 9 columns]

# %%
asset_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
# createdTime        1000 non-null int64
# depth              1000 non-null int64
# description        1000 non-null object
# id                 1000 non-null int64
# lastUpdatedTime    1000 non-null int64
# metadata           1000 non-null object
# name               1000 non-null object
# parentId           1000 non-null int64
# path               1000 non-null object
# dtypes: int64(5), object(4)
# memory usage: 70.4+ KB

# %% [markdown]
# We can visualize a single asset (so a single row) and its properties

# %%
asset_name = asset_df["name"][1] #2ND STAGE COMP DRY GAS SEAL SYS ON PH

# %%
asset_id = asset_df[asset_df["name"] == asset_name].iloc[0]['id']
client.assets.get_asset(asset_id=asset_id).to_pandas()
# Out:
#                                                                  0
# id                                                3904753668320840
# depth                                                            7
# name                         23-1ST STAGE COMP DRY GAS SEAL SYS-PH
# parentId                                          4856008121737468
# description                  1ST STAGE COMP DRY GAS SEAL SYS ON PH
# metadata         {'ELC_STATUS_ID': '1211', 'SOURCE_DB': 'workma...
# createdTime                                                      0
# lastUpdatedTime                                                  0
# path             [6687602007296940, 4650652196144007, 311145472...

# %% [markdown]
# As we have seen, each Asset has various properties, among which:
# - Id: its own Id
# - Depth: Sub assets up to this many levels below the specified path, i.e. the number of edges from the parent node
# - Name: its own name
# - ParentId: the Id of its parent Asset
# - Description: Search query, which includes information such as the platform and type of sensor being monitored
# - Metadata: The metadata values used to filter the results
#
#
# etc..

# %% [markdown]
# We can fetch an asset subtree using get_asset_subtree().
# We can start by specifying a depth of 1, so that we get the subassets 1 level below the asset 23-HA-9107B.

# %%
subassets = client.assets.get_asset_subtree(asset_id=asset_id, depth=1).to_pandas()
subassets.head()
# Out:
#    createdTime  depth                                   description  \
# 0            0      7         1ST STAGE COMP DRY GAS SEAL SYS ON PH
# 1            0      8                VRD - PH 1STSTG COMP SEPAR GAS
# 2            0      8  VRD - 1ST STAGE COMPRESSOR NITROGEN FILTER B
# 3            0      8           VRD - PH 1STSTG COMP OUTER SEAL NDE
# 4            0      8  VRD - 1ST STAGE COMPRESSOR GAS SEAL FILTER A
#
#                  id  lastUpdatedTime  \
# 0  3904753668320840                0
# 1   311006305196759                0
# 2   928299407571359                0
# 3  1129133419719764                0
# 4  1510541513998137                0
#
#                                             metadata  \
# 0  {'ELC_STATUS_ID': '1211', 'SOURCE_DB': 'workma...
# 1  {'ELC_STATUS_ID': '1211', 'RES_ID': '532915', ...
# 2  {'ELC_STATUS_ID': '1211', 'SOURCE_DB': 'workma...
# 3  {'ELC_STATUS_ID': '1211', 'RES_ID': '495058', ...
# 4  {'ELC_STATUS_ID': '1211', 'SOURCE_DB': 'workma...
#
#                                     name          parentId  \
# 0  23-1ST STAGE COMP DRY GAS SEAL SYS-PH  4856008121737468
# 1                         23-PT-96160-01  3904753668320840
# 2                            23-CB-9129B  3904753668320840
# 3                         23-PT-96157-02  3904753668320840
# 4                            23-CB-9104A  3904753668320840
#
#                                                 path
# 0  [6687602007296940, 4650652196144007, 311145472...
# 1  [6687602007296940, 4650652196144007, 311145472...
# 2  [6687602007296940, 4650652196144007, 311145472...
# 3  [6687602007296940, 4650652196144007, 311145472...
# 4  [6687602007296940, 4650652196144007, 311145472...

# %% [markdown]
# What we basically do now is: for each subasset we get its time-series and merge it into a dataframe

# %%
all_ts_df = pd.DataFrame()

for index, asset in subassets.iterrows():
  ts_df = client.time_series.get_time_series(asset_id=int(asset['id'])).to_pandas()
  
  if not ts_df.empty:
    all_ts_df = all_ts_df.append(ts_df, ignore_index=True)
    
all_ts_df
# Out:
#              assetId  createdTime                      description  \
# 0    311006305196759            0   PH 1st Stg Comp Separation Gas
# 1   1129133419719764            0        PH 1st Stg Outer Seal NDE
# 2   2456441663607972            0        PH 1st Stg Outer Seal NDE
# 3   2539007469802785            0        PH 1stStg Seal Gas Heater
# 4   2539007469802785            0        PH 1stStg Seal Gas Heater
# 5   4050790831683279            0  PH 1st Stg Comp Over Inner Seal
# 6   4050790831683279            0        PH 1st Stg Inner Seal NDE
# 7   4239585628663887            0     PH 1stStg Comp Inner Seal DE
# 8   5784138902448314            0   PH 1st Stg Comp Separation Gas
# 9   6223287279641772            0  PH 1st Stage Comp Inner Seal DE
# 10  6980863755677411            0    PH 1stStg Comp Balance Piston
# 11  7080547672061222            0       PH 1st Stg Comp Inner Seal
# 12  7314196130664807            0        PH 1st Stg Inner Seal NDE
# 13  7355334418846746            0  PH 1st Stg Comp Over Inner Seal
# 14  7355334418846746            0  PH 1st Stage Comp Inner Seal DE
# 15  7969520025805252            0    PH 1stStg Comp Inner Seal NDE
# 16  8607625175826542            0   PH 1st Stg Comp Separation Gas
#
#                   id  isStep  isString  lastUpdatedTime  \
# 0   8448039626216272   False     False                0
# 1    527653744772094   False     False                0
# 2    813184639383284   False     False                0
# 3   5769675878102582   False     False                0
# 4   8417055044933511   False     False                0
# 5    713200317738867   False     False                0
# 6   3054990494708797   False     False                0
# 7    712404469104819   False     False                0
# 8   4249054303737874   False     False                0
# 9    362924890178640   False     False                0
# 10  7433885982156917   False     False                0
# 11  5652117878397785   False     False                0
# 12  3865381295713151   False     False                0
# 13  7314540634514768   False     False                0
# 14  1503904203676739   False     False                0
# 15  7804057584240254   False     False                0
# 16  8912288909702706   False     False                0
#
#                                                  name
# 0                          VAL_23-PT-96160:Z.X1.Value
# 1                          VAL_23-PT-96157:Z.X2.Value
# 2                          VAL_23-PT-96157:Z.X1.Value
# 3   VAL_23-FE-9122-H01-F-EL:XS.MeasuredValues.Curr...
# 4                      VAL_23-FE-9122-H01-F:Z.Y.Value
# 5                            VAL_23-PDI-96150:X.Value
# 6                          VAL_23-PT-96150:Z.X1.Value
# 7                             VAL_23-FT-96151:X.Value
# 8                          VAL_23-PT-96160:Z.X2.Value
# 9                          VAL_23-PT-96149:Z.X2.Value
# 10                           VAL_23-PDT-96167:X.Value
# 11                            VAL_23-TT-96168:X.Value
# 12                         VAL_23-PT-96150:Z.X2.Value
# 13                           VAL_23-PDI-96149:X.Value
# 14                         VAL_23-PT-96149:Z.X1.Value
# 15                            VAL_23-FT-96152:X.Value
# 16                         VAL_23-PT-96160-03:X.Value

# %% [markdown]
# #### View datapoints for each one of the time series
# A Datapoint in the CDP is stored as a key value pair
# - timestamp is the time since epoch in milliseconds
# - value is the value which is read from the sensor

# %%
client.datapoints.get_datapoints(name=all_ts_df['name'][0], start="30d-ago").to_pandas().head()
# Out:
#        timestamp      value
# 0  1547819099291  57.301441
# 1  1547819100291  57.354084
# 2  1547819101291  57.617302
# 3  1547819102291  57.196156
# 4  1547819103291  57.617302
